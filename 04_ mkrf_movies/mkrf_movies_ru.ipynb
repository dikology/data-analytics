# %% [markdown]
# # Исследование данных о российском кинопрокате

# %% [markdown]
# Заказчик этого исследования — Министерство культуры Российской Федерации.
#
# Нужно изучить рынок российского кинопроката и выявить текущие тренды. Уделить внимание фильмам, которые получили государственную поддержку.
#
# Будем работать с данными, опубликованными на [портале открытых данных Министерства культуры](http://opendata.mkrf.ru/). Набор данных содержит информацию о прокатных удостоверениях, сборах и государственной поддержке фильмов, а также информацию с сайта КиноПоиск.
#
# ### Цели
# Ответить на вопрос, насколько фильмы с государственной поддержкой интересны зрителю.
#
# ### Описание данных
# Таблица `mkrf_movies` содержит информацию из реестра прокатных удостоверений. У одного фильма может быть несколько прокатных удостоверений.
#
# - `title` — название фильма;
# - `puNumber` — номер прокатного удостоверения;
# - `show_start_date` — дата премьеры фильма;
# - `type` — тип фильма;
# - `film_studio` — студия-производитель;
# - `production_country` — страна-производитель;
# - `director` — режиссёр;
# - `producer` — продюсер;
# - `age_restriction` — возрастная категория;
# - `refundable_support` *—* объём возвратных средств государственной поддержки;
# - `nonrefundable_support` *—* объём невозвратных средств государственной поддержки;
# - `financing_source` *—* источник государственного финансирования;
# - `budget` *—* общий бюджет фильма;
# - `ratings` *—* рейтинг фильма на КиноПоиске;
# - `genres` *—* жанр фильма.
#
# Столбец `budget` уже включает в себя полный объём государственной поддержки. Данные в этом столбце указаны только для тех фильмов, которые получили государственную поддержку.
#
# Таблица `mkrf_shows` содержит сведения о показах фильмов в российских кинотеатрах.
#
# - `puNumber` — номер прокатного удостоверения;
# - `box_office` — сборы в рублях.
#
# ### План работ
#
# **Шаг 1.** **Изучим файлы с данными**
# 1. Загрузим данные из файлов в датафрейм.
# 2. Изучим общую информацию о полученном датафрейме.
#
# **Шаг 2. Предобработка данных**
#
# 1. Найдём и изучим пропущенные значения в столбцах
# 2. Рассмотрим типы данных в каждом столбце
# 3. Изучим уникальные значения и дубликаты
#
# **Шаг 3. Проведём исследовательский анализ данных:**
#
# 1. Изучим параметры фильмов
# 2. Посмотрим, какие факторы больше всего влияют на целевые задачи исследования
#
# **Шаг 5. Сделаем выводы и дадим рекомендации**

# %% [markdown]
# ## Знакомство с данными

# %%
# импорт библиотек
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Избавимся от экспоненты
pd.options.display.float_format = '{:,.1f}'.format

# %%
# загружаем датасет из файла
try:
    # в качестве разделителя колонок используется запятая
    data1 = pd.read_csv('/datasets/mkrf_movies.csv')
    data2 = pd.read_csv('/datasets/mkrf_shows.csv')
except:
    # в качестве разделителя колонок используется запятая
    data1 = pd.read_csv('../datasets/mkrf_movies.csv')
    data2 = pd.read_csv('../datasets/mkrf_shows.csv')

# %%
# выведем первые 5 строк датасета для ознакомления
data1.head()
# Out:
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
# 2          Особо опасен  221038416  2016-10-10T12:00:00.000Z  Художественный
# 3          Особо опасен  221026916  2016-06-10T12:00:00.000Z  Художественный
# 4          Особо опасен  221030815  2015-07-29T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                                NaN
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 NaN                    NaN
# 1  «6+» - для детей старше 6 лет                 NaN                    NaN
# 2    «18+» - запрещено для детей                 NaN                    NaN
# 3    «18+» - запрещено для детей                 NaN                    NaN
# 4    «18+» - запрещено для детей                 NaN                    NaN
#
#    budget financing_source ratings                     genres
# 0     NaN              NaN     7.2     боевик,драма,мелодрама
# 1     NaN              NaN     6.6              драма,военный
# 2     NaN              NaN     6.8  фантастика,боевик,триллер
# 3     NaN              NaN     6.8  фантастика,боевик,триллер
# 4     NaN              NaN     6.8  фантастика,боевик,триллер

# %% [markdown]
# - Есть пропуски
# - Есть дублирующиеся названия (с разными прокатными удостоверениями - в описании к данным об этом говорилось)
# - Много категорийных столбцов с текстовым наполнением - это потенциально может приводить к неявным дубликатам из-за лишних символов, неодинакового порядка перечислений или различных разделителей

# %%
# общая информация о датафрейме
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7486 entries, 0 to 7485
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7486 non-null   object
#  1   puNumber               7486 non-null   object
#  2   show_start_date        7486 non-null   object
#  3   type                   7486 non-null   object
#  4   film_studio            7468 non-null   object
#  5   production_country     7484 non-null   object
#  6   director               7477 non-null   object
#  7   producer               6918 non-null   object
#  8   age_restriction        7486 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
#  14  genres                 6510 non-null   object
# dtypes: float64(3), object(12)
# memory usage: 877.4+ KB

# %% [markdown]
# - Всего 7486 строк
# - Данные о государственной поддержке только у 332 фильмов
# - Есть пропуски во многих столбцах

# %%
# посмотрим на второй датафрейм
data2.head()
# Out:
#     puNumber    box_office
# 0  111000113       2,450.0
# 1  111000115      61,040.0
# 2  111000116 153,030,013.4
# 3  111000117  12,260,956.0
# 4  111000118 163,684,057.8

# %%
# общая информация о датафрейме
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3158 entries, 0 to 3157
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   puNumber    3158 non-null   int64
#  1   box_office  3158 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 49.5 KB

# %% [markdown]
# Тип данных `puNumber` в датафреймах не совпадает - `object` и `int64`.
# При попытке приведения к `int64` столкнулись с аномальным значением `нет`.

# %%
# смотрим, много ли аномальных значений
data1.query('puNumber == "нет"')
# Out:
#                                   title puNumber           show_start_date  \
# 1797  Курбан-роман. (История с жертвой)      нет  2014-05-15T12:00:00.000Z
#
#                 type       film_studio production_country director  \
# 1797  Художественный  ФОНД "ИННОВАЦИЯ"             Россия  С.Юзеев
#
#         producer                  age_restriction  refundable_support  \
# 1797  М.Галицкая  «12+» - для детей старше 12 лет                 NaN
#
#       nonrefundable_support  budget financing_source ratings genres
# 1797                    NaN     NaN              NaN     NaN    NaN

# %% [markdown]
# такое значение встречается только одно. Это фильм без господдержки, у него нет рейтинга. Решаем удалить эту строку из датасета.

# %%
# удаляем строку с аномальным значением из датасета
data1 = data1.drop(labels=1797, axis=0)

# %%
# приводим тип данных прокатного удостоверения в первом датафрейме к int64
data1 = data1.astype({'puNumber' : 'int64'})
data1.dtypes
# Out:
# title                     object
# puNumber                   int64
# show_start_date           object
# type                      object
# film_studio               object
# production_country        object
# director                  object
# producer                  object
# age_restriction           object
# refundable_support       float64
# nonrefundable_support    float64
# budget                   float64
# financing_source          object
# ratings                   object
# genres                    object
# dtype: object

# %%
# Объединяем датафреймы по параметру puNumber таким образом, 
# чтобы все объекты из датасета `mkrf_movies` вошли в получившийся датафрейм. 
data = data1.merge(data2, how='left', on='puNumber')
data.head()
# Out:
#                   title   puNumber           show_start_date            type  \
# 0      Открытый простор  221048915  2015-11-27T12:00:00.000Z  Художественный
# 1  Особо важное задание  111013716  2016-09-13T12:00:00.000Z  Художественный
# 2          Особо опасен  221038416  2016-10-10T12:00:00.000Z  Художественный
# 3          Особо опасен  221026916  2016-06-10T12:00:00.000Z  Художественный
# 4          Особо опасен  221030815  2015-07-29T12:00:00.000Z  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                                NaN
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 NaN                    NaN
# 1  «6+» - для детей старше 6 лет                 NaN                    NaN
# 2    «18+» - запрещено для детей                 NaN                    NaN
# 3    «18+» - запрещено для детей                 NaN                    NaN
# 4    «18+» - запрещено для детей                 NaN                    NaN
#
#    budget financing_source ratings                     genres  box_office
# 0     NaN              NaN     7.2     боевик,драма,мелодрама         NaN
# 1     NaN              NaN     6.6              драма,военный         NaN
# 2     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 3     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 4     NaN              NaN     6.8  фантастика,боевик,триллер         NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7485 entries, 0 to 7484
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  7485 non-null   object
#  1   puNumber               7485 non-null   int64
#  2   show_start_date        7485 non-null   object
#  3   type                   7485 non-null   object
#  4   film_studio            7467 non-null   object
#  5   production_country     7483 non-null   object
#  6   director               7476 non-null   object
#  7   producer               6917 non-null   object
#  8   age_restriction        7485 non-null   object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                6519 non-null   object
#  14  genres                 6510 non-null   object
#  15  box_office             3158 non-null   float64
# dtypes: float64(4), int64(1), object(11)
# memory usage: 994.1+ KB

# %%
# переименуем столбец puNumber в pu_number
data = data.rename(columns={'puNumber':'pu_number'})

# %%
# проверяем объединение
data.shape
# Out:
# (7485, 16)

# %% [markdown]
# Количество строк сохранилось, столбец из второго файла добавился

# %%
# посмотрим на пропуски
data.isna().sum()
# Out:
# title                       0
# pu_number                   0
# show_start_date             0
# type                        0
# film_studio                18
# production_country          2
# director                    9
# producer                  568
# age_restriction             0
# refundable_support       7153
# nonrefundable_support    7153
# budget                   7153
# financing_source         7153
# ratings                   966
# genres                    975
# box_office               4327
# dtype: int64

# %%
# описание количественных данных
data.describe()
# Out:
#           pu_number  refundable_support  nonrefundable_support  \
# count       7,485.0               332.0                  332.0
# mean  135,196,587.6        11,864,457.8           48,980,988.9
# std    38,352,919.3        24,916,555.3           59,980,117.9
# min     1,811,096.0                 0.0                    0.0
# 25%   112,025,118.0                 0.0           25,000,000.0
# 50%   121,015,510.0                 0.0           30,000,000.0
# 75%   124,003,314.0        15,000,000.0           40,375,000.0
# max   231,001,111.0       180,000,000.0          400,000,000.0
#
#                budget      box_office
# count           332.0         3,158.0
# mean    127,229,716.7    76,478,696.2
# std     188,588,333.1   240,353,122.8
# min               0.0             0.0
# 25%      42,000,000.0        86,239.0
# 50%      68,649,916.0     2,327,987.5
# 75%     141,985,319.5    23,979,671.0
# max   2,305,074,303.0 3,073,568,690.8

# %%
# типы данных
data.dtypes
# Out:
# title                     object
# pu_number                  int64
# show_start_date           object
# type                      object
# film_studio               object
# production_country        object
# director                  object
# producer                  object
# age_restriction           object
# refundable_support       float64
# nonrefundable_support    float64
# budget                   float64
# financing_source          object
# ratings                   object
# genres                    object
# box_office               float64
# dtype: object

# %%
data.hist(figsize=(9,9))
plt.show()

# %%
# проверим, есть ли полные дубликаты 
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Промежуточные итоги

# %% [markdown]
# Мы считали данные из двух файлов и объединили датафреймы по номеру прокатного утостоверения
# Мы столкнулись с несоответствием типов данных этого столбца в разных датафреймах, и нашли аномальное значение, от которого решили избавиться (удалить строку)
# Остался единый датафрейм из 7485 строк и 16 столбцов
#
# - Есть пропуски
# - Есть дублирующиеся названия (с разными прокатными удостоверениями - в описании к данным об этом говорилось)
# - Много категорийных столбцов с текстовым наполнением - это потенциально может приводить к неявным дубликатам из-за лишних символов, неодинакового порядка перечислений или различных разделителей

# %% [markdown]
# ## Шаг 2. Предобработка данных

# %%
# создадим отдельную переменную для очищенных данных
clean_data = data.copy()

# %% [markdown]
# ### Шаг 2.1. Типы данных
#
# - Проверим типы данных в датафрейме и преобразуем их там, где это необходимо.

# %%
# ещё раз выведем типы данных
clean_data.dtypes
# Out:
# title                     object
# pu_number                  int64
# show_start_date           object
# type                      object
# film_studio               object
# production_country        object
# director                  object
# producer                  object
# age_restriction           object
# refundable_support       float64
# nonrefundable_support    float64
# budget                   float64
# financing_source          object
# ratings                   object
# genres                    object
# box_office               float64
# dtype: object

# %% [markdown]
# - `show_start_date` — дата премьеры фильма - преобразуем в `datetime`
# - `ratings` *—* рейтинг фильма на КиноПоиске - преобразуем в `float`, (в столбце много пустых значений)
#
# Категорийные столбцы оставим строковыми

# %%
# применяем datetime для даты премьеры фильма
clean_data['show_start_date'] = pd.to_datetime(clean_data['show_start_date'])

# %% [markdown]
# при попытке приведения типа данных рейтинга выяснилось, что там есть значения с %

# %%
# посмотрим на данные с процентным рейтингом
clean_data[clean_data['ratings'].str.contains('%', na=False)].head()
# Out:
#                      title  pu_number           show_start_date  \
# 259                Прошлое  221030715 2015-07-29 12:00:00+00:00
# 811              От винта!  114000212 2012-08-06 12:00:00+00:00
# 1053      Песочный человек  121029212 2012-11-29 12:00:00+00:00
# 1341  Сказка о добре и Вре  111008913 2013-11-15 12:00:00+00:00
# 1804              Спираль.  111001014 2014-01-30 12:00:00+00:00
#
#                 type                                        film_studio  \
# 259   Художественный  20 Сенчюри Фокс де Архентина, Чемо, ЭйчБи Филм...
# 811     Анимационный                  ЗАО "Продюсерский центр "Парадиз"
# 1053  Художественный                            Спотлайт Медиа Продакшн
# 1341  Художественный                     НП "Студия игрового кино "Лик"
# 1804  Художественный                               ООО "Компания Питон"
#
#         production_country       director  \
# 259   Аргентина - Бразилия  Эктор Бабенко
# 811                 Россия       О.Лопато
# 1053             Швейцария    Питер Луизи
# 1341                Россия      Е.Шиляева
# 1804                Россия       А.Волгин
#
#                                       producer  \
# 259   Эктор Бабенко, Оскар Крамер, Хуго Сидмэн
# 811        Г.Нерсисян, А.Манасарян, А.Нерсесян
# 1053                  Дэвид Луизи, Питер Луизи
# 1341                               К.Терещенко
# 1804                                Е.Ковалева
#
#                       age_restriction  refundable_support  \
# 259   «16+» - для детей старше 16 лет                 NaN
# 811   «12+» - для детей старше 12 лет                 NaN
# 1053  «16+» - для детей старше 16 лет                 NaN
# 1341    «6+» - для детей старше 6 лет                 NaN
# 1804  «12+» - для детей старше 12 лет                 NaN
#
#       nonrefundable_support  budget financing_source ratings  \
# 259                     NaN     NaN              NaN     99%
# 811                     NaN     NaN              NaN     28%
# 1053                    NaN     NaN              NaN     97%
# 1341                    NaN     NaN              NaN     99%
# 1804                    NaN     NaN              NaN     99%
#
#                            genres  box_office
# 259           ужасы,триллер,драма         NaN
# 811   детский,приключения,комедия     1,740.0
# 1053     ужасы,фантастика,фэнтези         NaN
# 1341       триллер,драма,детектив         NaN
# 1804       аниме,мультфильм,ужасы     4,295.0

# %%
clean_data[clean_data['ratings'].str.contains('%', na=False)].count()
# Out:
# title                    29
# pu_number                29
# show_start_date          29
# type                     29
# film_studio              29
# production_country       29
# director                 29
# producer                 29
# age_restriction          29
# refundable_support        2
# nonrefundable_support     2
# budget                    2
# financing_source          2
# ratings                  29
# genres                   26
# box_office               15
# dtype: int64

# %% [markdown]
# Мы проверили на Кинопоиске несколько фильмов - рейтинг ошибочен не только форматированием, но и значением. Эти данные - всё равно что пропуски, заполним их NaN

# %%
# завершим преобразование
clean_data.loc[clean_data['ratings'].str.contains('%', na=False), 'ratings'] = np.nan
clean_data.astype({'ratings' : 'float'}).dtypes
# Out:
# title                                 object
# pu_number                              int64
# show_start_date          datetime64[ns, UTC]
# type                                  object
# film_studio                           object
# production_country                    object
# director                              object
# producer                              object
# age_restriction                       object
# refundable_support                   float64
# nonrefundable_support                float64
# budget                               float64
# financing_source                      object
# ratings                              float64
# genres                                object
# box_office                           float64
# dtype: object

# %% [markdown]
# ### Шаг 2.2. Пропуски в датафрейме

# %%
clean_data.isna().sum()
# Out:
# title                       0
# pu_number                   0
# show_start_date             0
# type                        0
# film_studio                18
# production_country          2
# director                    9
# producer                  568
# age_restriction             0
# refundable_support       7153
# nonrefundable_support    7153
# budget                   7153
# financing_source         7153
# ratings                   995
# genres                    975
# box_office               4327
# dtype: int64

# %% [markdown]
# - `film_studio` - если информации нет, можно заполнить значением `unknown`
# - `production_country` - если информации нет, можно заполнить значением `unknown`
# - `director` - если информации нет, можно заполнить значением `unknown`
# - `producer` - если информации нет, можно заполнить значением `unknown`
# - `refundable_support` - если информации нет, поддержки не было, можно заполнить `0`
# - `nonrefundable_support` - если информации нет, поддержки не было, можно заполнить `0`
# - `budget` - если информации нет, поддержки не было, но заполнить `0` кажется неправильно, так как бюджет всё же не нулевой
# - `financing_source` - если информации нет, поддержки не было, можно заполнить `none`
# - `ratings` - если информации нет, заполнить `0` кажется неправильно, так как рейтинг всё же не нулевой
# - `genres` - если информации нет, можно заполнить значением `unknown`
# - `box_office` - если информации нет, заполнить `0` кажется неправильно, так как рейтинг всё же не нулевой

# %%
# проверяем пустые значения 
clean_data[clean_data['film_studio'].isna()].head()
# Out:
#                          title  pu_number           show_start_date  \
# 1293           Stars in Shorts  121011114 2014-06-03 12:00:00+00:00
# 4440  Мульт личности. Выпуск 5  214000410 2010-01-25 12:00:00+00:00
# 6104              Значит любит  111013818 2018-08-10 12:00:00+00:00
# 6180     Несейка. Младшая дочь  112007018 2018-09-01 12:00:00+00:00
# 6378              Ян Антонышев  112011818 2018-11-15 12:00:00+00:00
#
#                  type film_studio   production_country  \
# 1293   Художественный         NaN  США, Великобритания
# 4440   Художественный         NaN                  NaN
# 6104   Художественный         NaN               Россия
# 6180   Документальный         NaN               Россия
# 6378   Документальный         NaN               Россия
#
#                                                director  \
# 1293  Роберт Фестингер, Руперт Френд, Джей Камен, Ни...
# 4440                                                NaN
# 6104                                        А.Краевский
# 6180                                            В.Марин
# 6378                                          Е.Окопная
#
#                                                producer  \
# 1293  Татьяна Келли, Роберта Мунро, Руперт Френд, До...
# 4440                                                NaN
# 6104                                        Е.Щербакова
# 6180                    Д.Якунин, Ф.Абрютин, О.Филонова
# 6378                                        Е.Герасимов
#
#                              age_restriction  refundable_support  \
# 1293         «16+» - для детей старше 16 лет                 NaN
# 4440  «0+» - для любой зрительской аудитории                 NaN
# 6104             «18+» - запрещено для детей                 NaN
# 6180           «6+» - для детей старше 6 лет                 NaN
# 6378         «12+» - для детей старше 12 лет                 NaN
#
#       nonrefundable_support  budget financing_source ratings  \
# 1293                    NaN     NaN              NaN     7.3
# 4440                    NaN     NaN              NaN     4.0
# 6104                    NaN     NaN              NaN     NaN
# 6180                    NaN     NaN              NaN     NaN
# 6378                    NaN     NaN              NaN     NaN
#
#                   genres  box_office
# 1293             комедия         NaN
# 4440  мультфильм,комедия         NaN
# 6104                 NaN         NaN
# 6180                 NaN         NaN
# 6378                 NaN         NaN

# %%
# заменим пропуски на unknown
clean_data['film_studio'] = clean_data['film_studio'].fillna('unknown')

# %%
# проверяем пустые значения 
clean_data[clean_data['production_country'].isna()]
# Out:
#                                                   title  pu_number  \
# 3185  Детский юмористический киножурнал "Ералаш. Ну ...  111001216
# 4440                           Мульт личности. Выпуск 5  214000410
#
#                show_start_date            type  \
# 3185 2016-02-09 12:00:00+00:00  Художественный
# 4440 2010-01-25 12:00:00+00:00  Художественный
#
#                           film_studio production_country  \
# 3185  ООО "Продюсерский центр ЕРАЛАШ"                NaN
# 4440                          unknown                NaN
#
#                                                director  \
# 3185  Р.Светлов, И.Магитон, А.Арутюнян, Л.Мирский, А...
# 4440                                                NaN
#
#                              producer                         age_restriction  \
# 3185  ООО "Продюсерский центр ЕРАЛАШ"  «0+» - для любой зрительской аудитории
# 4440                              NaN  «0+» - для любой зрительской аудитории
#
#       refundable_support  nonrefundable_support  budget financing_source  \
# 3185                 NaN                    NaN     NaN              NaN
# 4440                 NaN                    NaN     NaN              NaN
#
#      ratings              genres  box_office
# 3185     7.2     детский,комедия   194,527.0
# 4440     4.0  мультфильм,комедия         NaN

# %% [markdown]
# Судя по названиям, студиям и году выпуска, можно заполнить пустые значения `Россия`

# %%
# заменим пропуски на Россия
clean_data['production_country'] = clean_data['production_country'].fillna('Россия')

# %%
# проверяем пустые значения 
clean_data[clean_data['director'].isna()].head()
# Out:
#                                                   title  pu_number  \
# 764   Три звезды. Концерт в Waldbuhne Theater, Берли...  126003512
# 1735                           Помпеи. Британский музей  126003413
# 3839                     Зур концерт (Большой концерт).  217027010
# 4051  Ганс Сэйфуллин "Авылым чишмэлэре. Ганс Сэйфулл...  217017310
# 4297                        Изге Вэли (Святой Валентин)  217020610
#
#                show_start_date            type                   film_studio  \
# 764  2012-12-04 12:00:00+00:00          Прочие            Райзинг Алтернатив
# 1735 2013-09-11 12:00:00+00:00          Прочие  МортуСкрин, Британский музей
# 3839 2010-06-24 12:00:00+00:00  Художественный            ООО "Барс Рекордс"
# 4051 2010-04-22 12:00:00+00:00  Художественный            ООО "Барс-Рекордс"
# 4297 2010-05-20 12:00:00+00:00  Художественный            ООО "Барс Рекордс"
#
#      production_country director          producer  \
# 764      Великобритания      NaN   Вальдбюне Театр
# 1735     Великобритания      NaN  Британский музей
# 3839             Россия      NaN               NaN
# 4051             Россия      NaN               NaN
# 4297             Россия      NaN               NaN
#
#                              age_restriction  refundable_support  \
# 764   «0+» - для любой зрительской аудитории                 NaN
# 1735  «0+» - для любой зрительской аудитории                 NaN
# 3839         «12+» - для детей старше 12 лет                 NaN
# 4051  «0+» - для любой зрительской аудитории                 NaN
# 4297         «12+» - для детей старше 12 лет                 NaN
#
#       nonrefundable_support  budget financing_source ratings genres  \
# 764                     NaN     NaN              NaN     NaN    NaN
# 1735                    NaN     NaN              NaN     NaN    NaN
# 3839                    NaN     NaN              NaN     NaN    NaN
# 4051                    NaN     NaN              NaN     NaN    NaN
# 4297                    NaN     NaN              NaN     NaN    NaN
#
#       box_office
# 764     44,350.0
# 1735         NaN
# 3839         NaN
# 4051         NaN
# 4297         NaN

# %%
# заменим пропуски на unknown
clean_data['director'] = clean_data['director'].fillna('unknown')

# %%
# проверяем пустые значения 
clean_data[clean_data['producer'].isna()].head()
# Out:
#                    title  pu_number           show_start_date            type  \
# 1   Особо важное задание  111013716 2016-09-13 12:00:00+00:00  Художественный
# 5      Остановился поезд  111013816 2016-09-13 12:00:00+00:00  Художественный
# 6        Любовь и голуби  111007013 2013-10-18 12:00:00+00:00  Художественный
# 9    Отпуск за свой счет  111019114 2014-12-01 12:00:00+00:00  Художественный
# 11          Ответный ход  111019014 2014-12-01 12:00:00+00:00  Художественный
#
#                                film_studio production_country       director  \
# 1                    Киностудия "Мосфильм"               СССР      Е.Матвеев
# 5                    Киностудия "Мосфильм"               СССР   В.Абдрашитов
# 6                    Киностудия "Мосфильм"               СССР      В.Меньшов
# 9   Киностудия "Мосфильм", Телевидение ВНР      СССР, Венгрия        В.Титов
# 11                   Киностудия "Мосфильм"               СССР  М.Туманишвили
#
#    producer                  age_restriction  refundable_support  \
# 1       NaN    «6+» - для детей старше 6 лет                 NaN
# 5       NaN    «6+» - для детей старше 6 лет                 NaN
# 6       NaN  «12+» - для детей старше 12 лет                 NaN
# 9       NaN  «12+» - для детей старше 12 лет                 NaN
# 11      NaN  «12+» - для детей старше 12 лет                 NaN
#
#     nonrefundable_support  budget financing_source ratings  \
# 1                     NaN     NaN              NaN     6.6
# 5                     NaN     NaN              NaN     7.7
# 6                     NaN     NaN              NaN     8.3
# 9                     NaN     NaN              NaN     7.8
# 11                    NaN     NaN              NaN     7.8
#
#                       genres  box_office
# 1              драма,военный         NaN
# 5                      драма         NaN
# 6          мелодрама,комедия     2,700.0
# 9          мелодрама,комедия         NaN
# 11  боевик,драма,приключения         NaN

# %%
# заменим пропуски на unknown
clean_data['producer'] = clean_data['producer'].fillna('unknown')

# %%
# проверяем пустые значения 
clean_data[clean_data['refundable_support'].isna()].head()
# Out:
#                   title  pu_number           show_start_date            type  \
# 0      Открытый простор  221048915 2015-11-27 12:00:00+00:00  Художественный
# 1  Особо важное задание  111013716 2016-09-13 12:00:00+00:00  Художественный
# 2          Особо опасен  221038416 2016-10-10 12:00:00+00:00  Художественный
# 3          Особо опасен  221026916 2016-06-10 12:00:00+00:00  Художественный
# 4          Особо опасен  221030815 2015-07-29 12:00:00+00:00  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                            unknown
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 NaN                    NaN
# 1  «6+» - для детей старше 6 лет                 NaN                    NaN
# 2    «18+» - запрещено для детей                 NaN                    NaN
# 3    «18+» - запрещено для детей                 NaN                    NaN
# 4    «18+» - запрещено для детей                 NaN                    NaN
#
#    budget financing_source ratings                     genres  box_office
# 0     NaN              NaN     7.2     боевик,драма,мелодрама         NaN
# 1     NaN              NaN     6.6              драма,военный         NaN
# 2     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 3     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 4     NaN              NaN     6.8  фантастика,боевик,триллер         NaN

# %%
# так как не было гос поддержки, заменим на 0
clean_data['refundable_support'] = clean_data['refundable_support'].fillna(0)

# %%
# проверяем пустые значения 
clean_data[clean_data['nonrefundable_support'].isna()].head()
# Out:
#                   title  pu_number           show_start_date            type  \
# 0      Открытый простор  221048915 2015-11-27 12:00:00+00:00  Художественный
# 1  Особо важное задание  111013716 2016-09-13 12:00:00+00:00  Художественный
# 2          Особо опасен  221038416 2016-10-10 12:00:00+00:00  Художественный
# 3          Особо опасен  221026916 2016-06-10 12:00:00+00:00  Художественный
# 4          Особо опасен  221030815 2015-07-29 12:00:00+00:00  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                            unknown
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 0.0                    NaN
# 1  «6+» - для детей старше 6 лет                 0.0                    NaN
# 2    «18+» - запрещено для детей                 0.0                    NaN
# 3    «18+» - запрещено для детей                 0.0                    NaN
# 4    «18+» - запрещено для детей                 0.0                    NaN
#
#    budget financing_source ratings                     genres  box_office
# 0     NaN              NaN     7.2     боевик,драма,мелодрама         NaN
# 1     NaN              NaN     6.6              драма,военный         NaN
# 2     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 3     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 4     NaN              NaN     6.8  фантастика,боевик,триллер         NaN

# %%
# так как не было гос поддержки, заменим на 0
clean_data['nonrefundable_support'] = clean_data['nonrefundable_support'].fillna(0)

# %%
# проверяем пустые значения 
clean_data[clean_data['budget'].isna()].head()
# Out:
#                   title  pu_number           show_start_date            type  \
# 0      Открытый простор  221048915 2015-11-27 12:00:00+00:00  Художественный
# 1  Особо важное задание  111013716 2016-09-13 12:00:00+00:00  Художественный
# 2          Особо опасен  221038416 2016-10-10 12:00:00+00:00  Художественный
# 3          Особо опасен  221026916 2016-06-10 12:00:00+00:00  Художественный
# 4          Особо опасен  221030815 2015-07-29 12:00:00+00:00  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                            unknown
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 0.0                    0.0
# 1  «6+» - для детей старше 6 лет                 0.0                    0.0
# 2    «18+» - запрещено для детей                 0.0                    0.0
# 3    «18+» - запрещено для детей                 0.0                    0.0
# 4    «18+» - запрещено для детей                 0.0                    0.0
#
#    budget financing_source ratings                     genres  box_office
# 0     NaN              NaN     7.2     боевик,драма,мелодрама         NaN
# 1     NaN              NaN     6.6              драма,военный         NaN
# 2     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 3     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 4     NaN              NaN     6.8  фантастика,боевик,триллер         NaN

# %%
clean_data['budget'].value_counts()
# Out:
# 0.0              17
# 38,000,000.0      6
# 80,000,000.0      4
# 50,000,000.0      4
# 40,000,000.0      3
#                  ..
# 49,280,496.0      1
# 56,693,559.0      1
# 57,166,797.0      1
# 109,814,241.0     1
# 42,252,509.0      1
# Name: budget, Length: 290, dtype: int64

# %%
clean_data['budget'].isna().sum()
# Out:
# 7153

# %% [markdown]
# Решили не обнулять значения бюджета, но посмотрим на строки, в которых и так бюджет задан 0

# %%
clean_data[clean_data['budget'] == 0].head()
# Out:
#                     title  pu_number           show_start_date  \
# 2052                  14+  111023614 2014-12-19 12:00:00+00:00
# 2057            Дуxless 2  111000415 2015-01-26 12:00:00+00:00
# 2471          Воин (2015)  111017315 2015-09-28 12:00:00+00:00
# 2531              Бармен.  111009615 2015-05-26 12:00:00+00:00
# 2614  Савва. Сердце воина  114001715 2015-07-21 12:00:00+00:00
#
#                 type                                        film_studio  \
# 2052  Художественный                         ООО Киностудия  "Сентябрь"
# 2057  Художественный  ООО "Киностудия "Слово", ООО "Арт Пикчерс Студия"
# 2471  Художественный   ООО "Форпост Продакшн", ООО "Арт Пикчерс Студия"
# 2531  Художественный          АО "ВайТ Медиа", ООО "Арт Пикчерс Студия"
# 2614    Анимационный   ООО "Глюкоза Продакшн", ООО "Арт Пикчерс Студия"
#
#      production_country      director                            producer  \
# 2052             Россия      А.Зайцев                 О.Гранина, А.Зайцев
# 2057             Россия    Р.Прыгунов  П.Ануров, Ф.Бондарчук, Д.Рудовский
# 2471             Россия   А.Андрианов            ООО "Арт Пикчерс Студия"
# 2531             Россия  Д.Штурманова                         Т.Вайнштейн
# 2614             Россия      М.Фадеев                          А.Чистяков
#
#                       age_restriction  refundable_support  \
# 2052  «16+» - для детей старше 16 лет                 0.0
# 2057  «16+» - для детей старше 16 лет                 0.0
# 2471  «12+» - для детей старше 12 лет        10,000,000.0
# 2531  «16+» - для детей старше 16 лет        20,000,000.0
# 2614    «6+» - для детей старше 6 лет        60,000,000.0
#
#       nonrefundable_support  budget                  financing_source ratings  \
# 2052           23,000,000.0     0.0  Министерство культуры, Фонд кино     6.6
# 2057           75,000,000.0     0.0                         Фонд кино     6.6
# 2471           70,000,000.0     0.0                         Фонд кино     7.8
# 2531                    0.0     0.0                         Фонд кино     6.2
# 2614          100,000,000.0     0.0                         Фонд кино     4.6
#
#                               genres    box_office
# 2052                       мелодрама  10,234,016.1
# 2057                           драма 446,163,511.0
# 2471           боевик,драма,криминал 196,572,438.4
# 2531                 комедия,фэнтези  67,418,974.8
# 2614  мультфильм,приключения,фэнтези 184,487,551.4

# %% [markdown]
# Похоже на аномалию, так как по описанию Столбец `budget` уже включает в себя полный объём государственной поддержки. Данные в этом столбце указаны только для тех фильмов, которые получили государственную поддержку. Значит, он не может быть меньше суммы поддержки. Обработаем это далее.

# %%
# проверяем пустые значения 
clean_data[clean_data['ratings'].isna()].head()
# Out:
#                                                 title  pu_number  \
# 43           Мемуары гейши (по роману Артура Голдена)  121000606
# 150                                          Жди меня  111013615
# 154  Дом из песка и тумана (по книге Андре Дюбуи III)  221037813
# 159                                 Жемчужная девушка  224011014
# 227                                        Полустанок  111026714
#
#               show_start_date            type  \
# 43  2012-12-14 12:00:00+00:00  Художественный
# 150 2015-08-25 12:00:00+00:00  Художественный
# 154 2013-10-25 12:00:00+00:00  Художественный
# 159 2014-08-28 12:00:00+00:00  Художественный
# 227 2014-12-24 12:00:00+00:00  Художественный
#
#                                            film_studio production_country  \
# 43   Коламбия Пикчерз Корпорейшн, ДримУоркс ЭсКейДж...                США
# 150                              Киностудия "Мосфильм"               СССР
# 154                                    Кобальт Пикчерз                США
# 159  Чешское телевидение,Студия "Три брата" агентск...              Чехия
# 227                              Киностудия "Мосфильм"               СССР
#
#                 director                                           producer  \
# 43           Роб Маршалл  Стивен Спилберг, Люси Фишер, Дуглас Уик, Джон ...
# 150  А.Столпер, Б.Иванов                                            unknown
# 154      Вадим Перельман                                       Майкл Лондон
# 159        Владимир Дрга                                            unknown
# 227             Б.Барнет                                            unknown
#
#                             age_restriction  refundable_support  \
# 43          «12+» - для детей старше 12 лет                 0.0
# 150           «6+» - для детей старше 6 лет                 0.0
# 154         «16+» - для детей старше 16 лет                 0.0
# 159  «0+» - для любой зрительской аудитории                 0.0
# 227         «12+» - для детей старше 12 лет                 0.0
#
#      nonrefundable_support  budget financing_source ratings genres  box_office
# 43                     0.0     NaN              NaN     NaN    NaN         NaN
# 150                    0.0     NaN              NaN     NaN    NaN         NaN
# 154                    0.0     NaN              NaN     NaN    NaN         NaN
# 159                    0.0     NaN              NaN     NaN    NaN         NaN
# 227                    0.0     NaN              NaN     NaN    NaN         NaN

# %% [markdown]
# Решили не обнулять значения рейтинга

# %%
# проверяем пустые значения 
clean_data[clean_data['genres'].isna()].head()
# Out:
#                                                 title  pu_number  \
# 43           Мемуары гейши (по роману Артура Голдена)  121000606
# 150                                          Жди меня  111013615
# 154  Дом из песка и тумана (по книге Андре Дюбуи III)  221037813
# 159                                 Жемчужная девушка  224011014
# 227                                        Полустанок  111026714
#
#               show_start_date            type  \
# 43  2012-12-14 12:00:00+00:00  Художественный
# 150 2015-08-25 12:00:00+00:00  Художественный
# 154 2013-10-25 12:00:00+00:00  Художественный
# 159 2014-08-28 12:00:00+00:00  Художественный
# 227 2014-12-24 12:00:00+00:00  Художественный
#
#                                            film_studio production_country  \
# 43   Коламбия Пикчерз Корпорейшн, ДримУоркс ЭсКейДж...                США
# 150                              Киностудия "Мосфильм"               СССР
# 154                                    Кобальт Пикчерз                США
# 159  Чешское телевидение,Студия "Три брата" агентск...              Чехия
# 227                              Киностудия "Мосфильм"               СССР
#
#                 director                                           producer  \
# 43           Роб Маршалл  Стивен Спилберг, Люси Фишер, Дуглас Уик, Джон ...
# 150  А.Столпер, Б.Иванов                                            unknown
# 154      Вадим Перельман                                       Майкл Лондон
# 159        Владимир Дрга                                            unknown
# 227             Б.Барнет                                            unknown
#
#                             age_restriction  refundable_support  \
# 43          «12+» - для детей старше 12 лет                 0.0
# 150           «6+» - для детей старше 6 лет                 0.0
# 154         «16+» - для детей старше 16 лет                 0.0
# 159  «0+» - для любой зрительской аудитории                 0.0
# 227         «12+» - для детей старше 12 лет                 0.0
#
#      nonrefundable_support  budget financing_source ratings genres  box_office
# 43                     0.0     NaN              NaN     NaN    NaN         NaN
# 150                    0.0     NaN              NaN     NaN    NaN         NaN
# 154                    0.0     NaN              NaN     NaN    NaN         NaN
# 159                    0.0     NaN              NaN     NaN    NaN         NaN
# 227                    0.0     NaN              NaN     NaN    NaN         NaN

# %%
# заменим пропуски на unknown
clean_data['genres'] = clean_data['genres'].fillna('unknown')

# %%
# проверяем пустые значения 
clean_data[clean_data['box_office'].isna()].head()
# Out:
#                   title  pu_number           show_start_date            type  \
# 0      Открытый простор  221048915 2015-11-27 12:00:00+00:00  Художественный
# 1  Особо важное задание  111013716 2016-09-13 12:00:00+00:00  Художественный
# 2          Особо опасен  221038416 2016-10-10 12:00:00+00:00  Художественный
# 3          Особо опасен  221026916 2016-06-10 12:00:00+00:00  Художественный
# 4          Особо опасен  221030815 2015-07-29 12:00:00+00:00  Художественный
#
#                                          film_studio production_country  \
# 0  Тачстоун Пикчерз, Кобальт Пикчерз, Бикон Пикче...                США
# 1                              Киностудия "Мосфильм"               СССР
# 2  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 3  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
# 4  Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...                США
#
#             director                                           producer  \
# 0      Кевин Костнер          Дэвид Валдес, Кевин Костнер, Джейк Эбертс
# 1          Е.Матвеев                                            unknown
# 2  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 3  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4  Тимур Бекмамбетов  Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
#
#                  age_restriction  refundable_support  nonrefundable_support  \
# 0    «18+» - запрещено для детей                 0.0                    0.0
# 1  «6+» - для детей старше 6 лет                 0.0                    0.0
# 2    «18+» - запрещено для детей                 0.0                    0.0
# 3    «18+» - запрещено для детей                 0.0                    0.0
# 4    «18+» - запрещено для детей                 0.0                    0.0
#
#    budget financing_source ratings                     genres  box_office
# 0     NaN              NaN     7.2     боевик,драма,мелодрама         NaN
# 1     NaN              NaN     6.6              драма,военный         NaN
# 2     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 3     NaN              NaN     6.8  фантастика,боевик,триллер         NaN
# 4     NaN              NaN     6.8  фантастика,боевик,триллер         NaN

# %%
clean_data['box_office'].value_counts()
# Out:
# 0.0              24
# 200.0            13
# 300.0            12
# 360.0             9
# 400.0             8
#                  ..
# 9,585,014.0       1
# 809,638,458.6     1
# 220,728.0         1
# 11,332,412.0      1
# 52,984,377.0      1
# Name: box_office, Length: 2938, dtype: int64

# %%
clean_data[clean_data['box_office'] == 0].head()
# Out:
#                                                title  pu_number  \
# 66                                      Анна Павлова  111011013
# 237                                         Подранки  111007613
# 596                                    Запах вереска  111003012
# 914  В тумане /По одноименной повести Василя Быкова/  121027712
# 932                                  Письмо для Момо  124002912
#
#               show_start_date            type  \
# 66  2013-12-19 12:00:00+00:00  Художественный
# 237 2013-10-18 12:00:00+00:00  Художественный
# 596 2012-05-23 12:00:00+00:00  Художественный
# 914 2012-11-07 12:00:00+00:00  Художественный
# 932 2012-10-25 12:00:00+00:00    Анимационный
#
#                                            film_studio  \
# 66   совместное производство Киностудия "Мосфильм",...
# 237                              Киностудия "Мосфильм"
# 596                                   ООО "Студия РИМ"
# 914  Ма Йа Де Фикшн, Лемминг Филм, Беларусьфильм, Д...
# 932  Кадокава Пикчерз, Продакшнз И Джи, Токио Броад...
#
#                                     production_country        director  \
# 66                    СССР, Франция, Англия, Куба, ГДР    Эмиль Лотяну
# 237                                               СССР       Н.Губенко
# 596                                             Россия     А.Магомедов
# 914  Германия - Нидерланды - Беларусь - Россия - Ла...  Сергей Лозница
# 932                                             Япония  Окиура Хироюки
#
#                                             producer  \
# 66                                           unknown
# 237                                          unknown
# 596                            М.Балашова, Е.Миронов
# 914                                     Хайно Декерт
# 932  Хироюки Икеда, Митсухиса Ишикава, Кацзуя Хамана
#
#                      age_restriction  refundable_support  \
# 66     «6+» - для детей старше 6 лет                 0.0
# 237  «12+» - для детей старше 12 лет                 0.0
# 596  «16+» - для детей старше 16 лет                 0.0
# 914  «12+» - для детей старше 12 лет                 0.0
# 932  «12+» - для детей старше 12 лет                 0.0
#
#      nonrefundable_support  budget financing_source ratings  \
# 66                     0.0     NaN              NaN     7.7
# 237                    0.0     NaN              NaN     8.2
# 596                    0.0     NaN              NaN     6.3
# 914                    0.0     NaN              NaN     6.5
# 932                    0.0     NaN              NaN     7.4
#
#                      genres  box_office
# 66   драма,биография,музыка         0.0
# 237                   драма         0.0
# 596                 комедия         0.0
# 914   драма,военный,история         0.0
# 932  аниме,мультфильм,драма         0.0

# %%
# проверяем значения financing_source
clean_data['financing_source'].unique()
# Out:
# array([nan, 'Министерство культуры', 'Фонд кино',
#        'Министерство культуры, Фонд кино'], dtype=object)

# %%
# заменим пропуски на none
clean_data['financing_source'] = clean_data['financing_source'].fillna('none')

# %%
clean_data.isna().sum()
# Out:
# title                       0
# pu_number                   0
# show_start_date             0
# type                        0
# film_studio                 0
# production_country          0
# director                    0
# producer                    0
# age_restriction             0
# refundable_support          0
# nonrefundable_support       0
# budget                   7153
# financing_source            0
# ratings                   995
# genres                      0
# box_office               4327
# dtype: int64

# %% [markdown]
# Оставили три столбца с пропусками, чтобы не обнулять количественные значения:
# - `budget`
# - `ratings`
# - `box_office`

# %% [markdown]
# ### Шаг 2.3. Дубликаты в датафрейме
# - Проверим, есть ли в данных дубликаты.

# %%
clean_data.duplicated(subset=['title']).sum()
# Out:
# 714

# %% [markdown]
# Если проверять только по названию фильма, то дубликатов достаточно много. Однако в описании к данным указано, что у одного фильма может быть несколько прокатных удостоверений. Возможно, это и приводит к дубликатам.

# %%
clean_data.duplicated(subset=['pu_number']).sum()
# Out:
# 2

# %% [markdown]
# Есть дубликаты номеров прокатных удостоверений.

# %%
clean_data[clean_data.duplicated(subset=['pu_number'], keep=False)]
# Out:
#                                                   title  pu_number  \
# 4637                   Как жениться и остаться холостым  221154310
# 4638  Иоанна - женщина на папском престоле /По роман...  221154310
# 5066                                    Анализируй это!  221054410
# 5067                                     Анализируй то!  221054410
#
#                show_start_date            type  \
# 4637 2010-12-17 12:00:00+00:00  Художественный
# 4638 2010-12-17 12:00:00+00:00  Художественный
# 5066 2010-05-25 12:00:00+00:00  Художественный
# 5067 2010-05-25 12:00:00+00:00  Художественный
#
#                                             film_studio  \
# 4637  Ше Вам, Скрипт Ассосье, Тэ Фэ 1 Фильм Продюксь...
# 4638   Константин Фильм, А Эр Ди Дегето Фильм, Дюне ...
# 5066          Уорнер Бразерс, Вилладж Роудшоу Филмз ЛТД
# 5067  Уорнер Бразерс, Виллидж Роадшоу Пикчерз, Эн-Пи...
#
#                                 production_country        director  \
# 4637                                       Франция    Эрик Лартиго
# 4638  Германия - Великобритания - Италия - Испания  Зенке Вортманн
# 5066                                 США-Австралия   ХЭрольд Рэмис
# 5067                                           США  Гарольд Реймис
#
#                                         producer  \
# 4637                     Амандин Било, Алан Шаба
# 4638  Оливер Бербен, Дорис Д.Хайнце, Фарук Элтан
# 5066             Джейн Розенталь, Пола Уейнстейн
# 5067             Джейн Розенталь, Паул Уэйнстейн
#
#                       age_restriction  refundable_support  \
# 4637  «16+» - для детей старше 16 лет                 0.0
# 4638  «16+» - для детей старше 16 лет                 0.0
# 5066  «16+» - для детей старше 16 лет                 0.0
# 5067  «12+» - для детей старше 12 лет                 0.0
#
#       nonrefundable_support  budget financing_source ratings  \
# 4637                    0.0     NaN             none     7.0
# 4638                    0.0     NaN             none     7.6
# 5066                    0.0     NaN             none     7.4
# 5067                    0.0     NaN             none     6.8
#
#                        genres  box_office
# 4637        мелодрама,комедия         NaN
# 4638  драма,мелодрама,история         NaN
# 5066         комедия,криминал         NaN
# 5067         комедия,криминал         NaN

# %% [markdown]
# Фильмы разные, оставим как есть. Вероятно, ошибка в данных.

# %%
clean_data.duplicated(subset=['title', 'pu_number']).sum()
# Out:
# 0

# %% [markdown]
# Дубликатов по названию и удостоверению нет

# %% [markdown]
# Посмотрим дубликаты по набору столбцов, не включающих прокатное удостоверение и дату

# %%
# столбцы для копирования
clean_data.columns
# Out:
# Index(['title', 'pu_number', 'show_start_date', 'type', 'film_studio',
#        'production_country', 'director', 'producer', 'age_restriction',
#        'refundable_support', 'nonrefundable_support', 'budget',
#        'financing_source', 'ratings', 'genres', 'box_office'],
#       dtype='object')

# %%
# поиск дубликатов
clean_data.duplicated(subset=['title', 'type', 'film_studio',
       'production_country', 'director', 'producer', 'age_restriction',
       'refundable_support', 'nonrefundable_support', 'budget',
       'financing_source', 'ratings', 'genres', 'box_office']).sum()
# Out:
# 484

# %%
# вывод дубликатов
clean_data[clean_data.duplicated(subset=['title', 'type', 'film_studio',
       'production_country', 'director', 'producer', 'age_restriction',
       'refundable_support', 'nonrefundable_support', 'budget',
       'financing_source', 'ratings', 'genres', 'box_office'])].head()
# Out:
#                                                  title  pu_number  \
# 3                                         Особо опасен  221026916
# 4                                         Особо опасен  221030815
# 41                                        Алекс и Эмма  221004616
# 132  Джейн Эйр /По одноименному роману Шарлотты Бро...  221035716
# 205                                        Кинг Конг _  221001815
#
#               show_start_date            type  \
# 3   2016-06-10 12:00:00+00:00  Художественный
# 4   2015-07-29 12:00:00+00:00  Художественный
# 41  2016-02-09 12:00:00+00:00  Художественный
# 132 2016-06-07 12:00:00+00:00  Художественный
# 205 2015-02-11 12:00:00+00:00  Художественный
#
#                                            film_studio  \
# 3    Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...
# 4    Юниверсал Пикчерз, Кикстарт Продакшнз, Марк Пл...
# 41   Эскейп Артистс, Франчайз Пикчерз, Рейнер-Грэйс...
# 132  Чинеритино, Флаш Фильм, Медиасет, Мирамакс, Ро...
# 205  Биг Праймейт Пикчерз, Юниверсал Пикчерз, ВингН...
#
#                           production_country            director  \
# 3                                        США   Тимур Бекмамбетов
# 4                                        США   Тимур Бекмамбетов
# 41                                       США          Роб Райнер
# 132  Франция - Италия - Великобритания - США  Франко Дзеффирелли
# 205                     Новая Зеландия - США       Питер Джексон
#
#                                               producer  \
# 3    Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 4    Джим Лемли, Джейсон Нетер, Марк Е.Платт, Яйн Смит
# 41   Тодд Блэк, Элан Грейсман, Джереми Левен, Роб Р...
# 132                                            unknown
# 205  Йен Бленкин, Питер Джексон, Кэролайн Каннингэм...
#
#                      age_restriction  refundable_support  \
# 3        «18+» - запрещено для детей                 0.0
# 4        «18+» - запрещено для детей                 0.0
# 41   «16+» - для детей старше 16 лет                 0.0
# 132  «12+» - для детей старше 12 лет                 0.0
# 205  «16+» - для детей старше 16 лет                 0.0
#
#      nonrefundable_support  budget financing_source ratings  \
# 3                      0.0     NaN             none     6.8
# 4                      0.0     NaN             none     6.8
# 41                     0.0     NaN             none     6.4
# 132                    0.0     NaN             none     7.4
# 205                    0.0     NaN             none     7.6
#
#                         genres  box_office
# 3    фантастика,боевик,триллер         NaN
# 4    фантастика,боевик,триллер         NaN
# 41           мелодрама,комедия         NaN
# 132            драма,мелодрама         NaN
# 205     боевик,драма,мелодрама         NaN

# %%
# очистка дубликатов
clean_data.drop_duplicates(subset=['title', 'type', 'film_studio',
       'production_country', 'director', 'producer', 'age_restriction',
       'refundable_support', 'nonrefundable_support', 'budget',
       'financing_source', 'ratings', 'genres', 'box_office'], inplace=True)

# %%
# посмотрим на оставшиеся дубликаты по названиям
clean_data[clean_data.duplicated(subset=['title'], keep=False)].head()
# Out:
#                                                  title  pu_number  \
# 86                                           Валентина  111012713
# 109  Гарри Поттер и орден Феникса /По роману Дж.К.Р...  221004916
# 110  Гарри Поттер и орден Феникса /По роману Дж.К.Р...  121026316
# 111  Гарри Поттер и тайная комната /По роману Дж.К....  121026016
# 112  Гарри Поттер и узник Азкабана /По роману Дж.К....  221005016
#
#               show_start_date            type  \
# 86  2013-12-19 12:00:00+00:00  Художественный
# 109 2016-02-09 12:00:00+00:00  Художественный
# 110 2016-09-23 12:00:00+00:00  Художественный
# 111 2016-09-23 12:00:00+00:00  Художественный
# 112 2016-02-09 12:00:00+00:00  Художественный
#
#                                     film_studio    production_country  \
# 86                        Киностудия "Мосфильм"                  СССР
# 109                Уорнер Бразерс, Хэйдей Филмз  США - Великобритания
# 110                Уорнер Бразерс, Хэйдей Филмз  США - Великобритания
# 111    Уорнер Бразерс, Хедэй Филмз/1492 Пикчерз                   США
# 112  Хэйдей Филмз, 1492 Пикчерз, Уорнер Бразерс                   США
#
#             director                      producer  \
# 86        Г.Панфилов                       unknown
# 109       Дэвид Йетс  Дэйвид Баррон, Дэйвид Хейман
# 110       Дэвид Йетс  Дэйвид Баррон, Дэйвид Хейман
# 111    Крис Коламбус                 Дейвид Хейман
# 112  Альфонсо Куарон                 Майкл Барната
#
#                      age_restriction  refundable_support  \
# 86     «6+» - для детей старше 6 лет                 0.0
# 109  «16+» - для детей старше 16 лет                 0.0
# 110  «16+» - для детей старше 16 лет                 0.0
# 111  «12+» - для детей старше 12 лет                 0.0
# 112  «12+» - для детей старше 12 лет                 0.0
#
#      nonrefundable_support  budget financing_source ratings  \
# 86                     0.0     NaN             none     7.5
# 109                    0.0     NaN             none     7.7
# 110                    0.0     NaN             none     7.7
# 111                    0.0     NaN             none     8.0
# 112                    0.0     NaN             none     8.2
#
#                            genres  box_office
# 86                          драма         NaN
# 109  фэнтези,приключения,семейный         NaN
# 110  фэнтези,приключения,семейный   759,526.0
# 111  фэнтези,приключения,семейный 1,093,810.0
# 112  фэнтези,приключения,семейный         NaN

# %% [markdown]
# Есть дубликаты, для которых указан / не указан прокат `box_office`. Очистим и их тоже.

# %%
# поиск дубликатов
clean_data.duplicated(subset=['title', 'type', 'film_studio',
       'production_country', 'director', 'producer', 'age_restriction',
       'refundable_support', 'nonrefundable_support', 'budget',
       'financing_source', 'ratings', 'genres']).sum()
# Out:
# 178

# %%
# сортируем по наличию значения box_office и чистим дубликаты, оставляя первое вхождение
clean_data = clean_data.sort_values(by='box_office')
clean_data.drop_duplicates(subset=['title', 'type', 'film_studio',
       'production_country', 'director', 'producer', 'age_restriction',
       'refundable_support', 'nonrefundable_support', 'budget',
       'financing_source', 'ratings', 'genres'], inplace=True)

# %%
# проверяем после чистки
clean_data.duplicated(subset=['title', 'type', 'film_studio',
       'production_country', 'director', 'producer', 'age_restriction',
       'refundable_support', 'nonrefundable_support', 'budget',
       'financing_source', 'ratings', 'genres']).sum()
# Out:
# 0

# %%
# остатки дубликатов по названию
clean_data.duplicated(subset=['title'], keep=False).sum()
# Out:
# 101

# %%
clean_data[clean_data.duplicated(subset=['title'], keep=False)].sort_values(by='title').head(10)
# Out:
#                                                title  pu_number  \
# 7264  Альдабра: Путешествие по таинственному острову  126003719
# 3725  Альдабра: Путешествие по таинственному острову  126005616
# 6551                                        Аниматор  111024818
# 5835                                        Аниматор  111003818
# 7312                    Безумный Макс: Дорога ярости  121030019
# 2560                    Безумный Макс: Дорога ярости  121009615
# 6673                                    Большая игра  111001819
# 5670                                    Большая игра  121027917
# 3393                                   В тихом омуте  121018516
# 7449                                   В тихом омуте  121036919
#
#                show_start_date             type  \
# 7264 2019-09-30 12:00:00+00:00           Прочие
# 3725 2016-10-19 12:00:00+00:00           Прочие
# 6551 2018-12-26 12:00:00+00:00   Художественный
# 5835 2018-04-29 12:00:00+00:00   Художественный
# 7312 2019-12-06 12:00:00+00:00   Художественный
# 2560 2015-04-27 12:00:00+00:00   Художественный
# 6673 2019-02-28 12:00:00+00:00   Художественный
# 5670 2018-01-11 12:00:00+00:00   Художественный
# 3393 2016-06-21 12:00:00+00:00   Художественный
# 7449 2019-12-09 12:00:00+00:00   Художественный
#
#                                             film_studio  production_country  \
# 7264                                   Старлайт Пикчерз               Чехия
# 3725                                  Старлайт Пикчерз                Чехия
# 6551                                ООО "ФАВОРИТ МЕДИА"              Россия
# 5835   ЗАО "Кинокомпания ФаворитФильм" по заказу ООО...              Россия
# 7312                             Уорнер Бразерс Пикчерс      Австралия, США
# 2560  Кеннеди Миллер Продакшнз, Виллидж Роадшоу Пикч...     США - Австралия
# 6673  ООО "ГГФ" по заказу АО "Сеть телевизионных ста...              Россия
# 5670  Интертейнмент Уан, Паскаль Пикчерз, Марк Гордо...                 США
# 3393  Зэ Бэ Продуцион, Твенти Твенти Вижн Филмпродуц...  Германия - Франция
# 7449  Хэд Гир Филмз, Крео Филмз, Локал Хироу, Метрол...                 США
#
#                   director                                     producer  \
# 7264           Стив Лихтаг  Петр Келлер, Роберт Шнайдер, Леопольдо Гоут
# 3725           Стив Лихтаг  Леопольдо Гоут, Петр Келлер, Роберт Шнайдер
# 6551  А.Чижиков, И.Чижиков                        А.Чижиков, Н.Чижикова
# 5835  А.Чижиков, И.Чижиков                        А.Чижиков, Н.Чижикова
# 7312         Джордж Миллер      Джордж Миллер, Даг Митчелл, Брюс Берман
# 2560         Джордж Миллер                    Джордж Миллер, Дуг Митчел
# 6673            Б.Батуллин                                   А.Марченко
# 5670          Аарон Соркин                     Марк Гордон, Эми Паскаль
# 3393           Брюно Дюмон      Жан Бреа, Рашид Бушареб, Мюриэль Мерлин
# 7449          Адам Рэндолл                                  Мэтт Уолдек
#
#                       age_restriction  refundable_support  \
# 7264    «6+» - для детей старше 6 лет                 0.0
# 3725    «6+» - для детей старше 6 лет                 0.0
# 6551  «12+» - для детей старше 12 лет                 0.0
# 5835  «12+» - для детей старше 12 лет                 0.0
# 7312      «18+» - запрещено для детей                 0.0
# 2560  «16+» - для детей старше 16 лет                 0.0
# 6673  «16+» - для детей старше 16 лет                 0.0
# 5670      «18+» - запрещено для детей                 0.0
# 3393  «16+» - для детей старше 16 лет                 0.0
# 7449      «18+» - запрещено для детей                 0.0
#
#       nonrefundable_support  budget financing_source ratings  \
# 7264                    0.0     NaN             none     6.8
# 3725                    0.0     NaN             none     6.8
# 6551                    0.0     NaN             none     NaN
# 5835                    0.0     NaN             none     NaN
# 7312                    0.0     NaN             none     7.8
# 2560                    0.0     NaN             none     7.8
# 6673                    0.0     NaN             none     7.6
# 5670                    0.0     NaN             none     7.6
# 3393                    0.0     NaN             none     6.8
# 7449                    0.0     NaN             none     6.8
#
#                                    genres    box_office
# 7264  семейный,приключения,документальный           NaN
# 3725  семейный,приключения,документальный   5,484,100.4
# 6551                              unknown           NaN
# 5835                              unknown           NaN
# 7312        боевик,фантастика,приключения           NaN
# 2560        боевик,фантастика,приключения 650,165,993.5
# 6673             драма,криминал,биография           NaN
# 5670             драма,криминал,биография  77,806,917.3
# 3393            триллер,криминал,детектив   2,883,624.0
# 7449            триллер,криминал,детектив           NaN

# %% [markdown]
# Остальные дубликаты по названию могут оказаться разными фильмами, могут иметь разную запись в категориальных столбцах. Оставим их.

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6823 entries, 1782 to 7484
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  6823 non-null   object
#  1   pu_number              6823 non-null   int64
#  2   show_start_date        6823 non-null   datetime64[ns, UTC]
#  3   type                   6823 non-null   object
#  4   film_studio            6823 non-null   object
#  5   production_country     6823 non-null   object
#  6   director               6823 non-null   object
#  7   producer               6823 non-null   object
#  8   age_restriction        6823 non-null   object
#  9   refundable_support     6823 non-null   float64
#  10  nonrefundable_support  6823 non-null   float64
#  11  budget                 332 non-null    float64
#  12  financing_source       6823 non-null   object
#  13  ratings                5835 non-null   object
#  14  genres                 6823 non-null   object
#  15  box_office             3131 non-null   float64
# dtypes: datetime64[ns, UTC](1), float64(4), int64(1), object(10)
# memory usage: 906.2+ KB

# %% [markdown]
# ### Шаг 2.4. Категориальные значения

# %%
clean_data['type'].value_counts()
# Out:
# Художественный                3929
#  Художественный               1388
# Анимационный                   774
# Прочие                         395
# Документальный                 283
# Научно-популярный               52
# Музыкально-развлекательный       1
#  Анимационный                    1
# Name: type, dtype: int64

# %% [markdown]
# В поле `type` несколько значений, у которых появился пробел в начале строки.

# %%
clean_data['type'] = clean_data['type'].str.strip()

# %%
clean_data['type'].value_counts()
# Out:
# Художественный                5317
# Анимационный                   775
# Прочие                         395
# Документальный                 283
# Научно-популярный               52
# Музыкально-развлекательный       1
# Name: type, dtype: int64

# %%
clean_data['film_studio'].value_counts()
# Out:
# Киностудия "Мосфильм"                                                                                                                          339
# ООО "Мульт в кино"                                                                                                                              57
# Анимаккорд Лтд                                                                                                                                  23
# ООО "Мульт в кино"                                                                                                                              18
# unknown                                                                                                                                         17
#                                                                                                                                               ...
# Чинеритино, Флаш Фильм, Медиасет, Мирамакс, Рочестер, Мажестик Филмз                                                                             1
# Компани Филмз, Ди Бонавентура Пикчерз, Риверстоун Пикчерз, Ремстар Студиоз, Фундаментал Филмз, Лотос Интертейнмент, Оушн Парк Интертейнмент      1
# Коданша, Ликри, Никкатцу  Корпорейшн, Тохо Компани                                                                                               1
# 21 Лэпс Интертейнмент, ФилмНэйшн Интертейнмент, Лава Беар Филмз                                                                                  1
# Цивик Импекс                                                                                                                                     1
# Name: film_studio, Length: 5491, dtype: int64

# %% [markdown]
# Похоже, есть значения, у которых появился пробел в начале или конце строки.

# %%
clean_data['film_studio'] = clean_data['film_studio'].str.strip()

# %%
clean_data['film_studio'].value_counts()
# Out:
# Киностудия "Мосфильм"                                                                                                                                             343
# ООО "Мульт в кино"                                                                                                                                                 75
# Анимаккорд Лтд                                                                                                                                                     23
# ООО "ТаББаК"                                                                                                                                                       18
# unknown                                                                                                                                                            17
#                                                                                                                                                                  ...
# Импринт Интертейнмент, Саммит Интертейнмент, Тотал Интертейнмент, Тэ Сэ Бэ Дэ Канада Продюксьон, Тэ Си Би Ди Луизиана, Тэ Си Би Ди Продакшнз, Зохар Интернэшнл      1
# Хейдэй Филмз, Уорнер Бразерс                                                                                                                                        1
# Саммит Интертейнмент, Интрепид Пикчерз, Галавис Филм, Филм Райтс, Фриа Луз Дел Диа, Пикче Мэшин                                                                     1
# Мисс Ноубоди Продакшнз                                                                                                                                              1
# ХХ Век Фокс, Дэвис Интертейнмент, Тэ Эс Гэ Интертейнмент, Канада Филм Кэпитал, Дарк Кастл Интертейнмент                                                             1
# Name: film_studio, Length: 5463, dtype: int64

# %%
clean_data['production_country'].unique()
# Out:
# array(['Франция', 'Япония',
#        'Германия - Нидерланды - Беларусь - Россия - Латвия', 'Россия',
#        'Великобритания', 'СССР', 'США', 'Канада-Великобритания',
#        'Армения', 'Германия - Бельгия - США -Франция',
#        'Франция-Австралия', 'СССР, Франция, Англия, Куба, ГДР', 'Канада',
#        'Франция-Италия-Испания-Венгрия', 'Великобритания - Франция',
#        'Франция - Бельгия', 'СССР, Финляндия', 'Россия - Германия',
#        'Нидерланды', 'Япония - Канада', 'США - Новая Зеландия',
#        'Франция-Аргентина', 'Франция - Италия - Бельгия - Люксембург',
#        'Таиланд', 'Канада - Франция - Великобритания', 'Южная Корея',
#        'Украина', 'Ирландия - Дания - Бельгия - Люксембург - Франция',
#        'Россия-Германия', 'СССР, Румыния, Франция', 'Германия',
#        'Финляндия - Канада', 'Россия, Казахстан, США',
#        'Сербия - Германия - Венгрия', 'Франция - Швейцария - Германия',
#        'Франция-Великобритания', 'Франция - Бельгия - Люксембург',
#        'США - Бельгия', 'Канада - США', 'Дания', 'Германия - США',
#        'Италия', 'Польша - Португалия - Франция - Великобритания',
#        'США - Великобритания - КНР', 'США - Австралия', 'США-Германия',
#        'СССР, ЧССР, Западный Берлин, ПНР', 'США-Германия-Великобритания',
#        'Россия-Украина-Германия', 'Германия-Франция-Великобритания-США',
#        'США-Индия', 'США - Великобритания', 'США-Китай', 'Испания',
#        'Австралия - США', 'Новая Зеландия', 'СССР ',
#        'Россия, Республика Беларусь', 'США - Канада', 'США-КНР',
#        'Франция-Канада', 'Франция - США',
#        'Великобритания - Израиль - Франция - Япония - США',
#        'Франция-Перу', 'СССР - Швейцария - Франция',
#        'Германия - США - Швеция - Франция', 'Швейцария-Германия-ЮАР',
#        'США - Франция', 'Франция - Украина - Грузия - Армения',
#        'США-Бельгия', 'Австралия', 'Франция - Греция',
#        'Финляндия - Дания - Германия - Ирландия', 'Румыния-США',
#        'Мексика - Аргентина - Великобритания', 'Иран',
#        'Франция - Германия',
#        'Великобритания - Франция - Швеция - Бельгия', 'Южная Корея - КНР',
#        'Великобритания-Австралия - США', 'Германия-США', 'Норвегия',
#        'США-ОАЭ', 'Россия - Польша', 'Канада - КНР', 'США ',
#        'Великобритания - Германия', 'Германия - Франция - Польша', 'КНР',
#        'Дания - Швеция', 'Франция ', 'США-Испания',
#        'Испания - Уругвай - Аргентина', 'Великобритания-Венгрия',
#        'Бразилия - Канада - США', 'Великобритания - США',
#        'Канада - Франция', 'Бельгия', 'Австрия', 'Гонконг',
#        'Дания - Германия',
#        'Великобритания - Польша - КНР - Индия - Норвегия',
#        'Италия - Россия', 'Германия - Италия', 'США-Австралия',
#        'Франция - Бенльгия', 'Дания - Великобритания - ЮАР',
#        'США - Япония', 'Нидерланды - Россия - Германия',
#        'Россия-Казахстан', 'Дания-Швеция-Франция-Германия',
#        'Великобритания - США - Индия', 'Казахстан',
#        'США - Россия - Франция', 'США - Южная Корея',
#        'Болгария - Франция - Изриль', 'Франция-Испания-Швейцария',
#        'Республика Кипр', 'Германия - Китай', 'США - КНР',
#        'Великобритания - Германия - Франция - Кипр - США',
#        'Гонконг - КНР', 'Южная Корея - США',
#        'Аргентина - Уругвай - Россия - Германия - Франция - Нидерланды',
#        'Турция - Германя - Франция', 'Польша - Франция',
#        'Великобритания - Италия - Швейцария',
#        'США - Румыния - Великобритания',
#        'Великобритания - Норвегия - Дания - Германия', 'США-Япония',
#        'США - Великобритания- Франция - Швеция', 'США-Франция-Канада',
#        'Южная Корея - США - Канада', 'Россия-Белоруссия',
#        'Испания - США - Колумбия', 'Великобритания - Франция - Италия',
#        'Испания - Италия - Франция', 'Канада-Франция', 'США-ЮАР',
#        'США-Франция', 'США - Индия', 'Индия',
#        'Бельгия - Италия - Франция ',
#        'Дания-Франция-Бельгия-Германия-Великобритания', 'Россия-Франция',
#        'США-Италия-Испания', 'Эстония - Россия', 'Республика Казахстан',
#        'Малайзия - США', 'Россия, Грузия, Испания',
#        'Германия - Италия - Франция', 'ЮАР',
#        'Швеция - Франция - Норвегия - Дания',
#        'Аргентина - Мексика - Бразилия - Франция - США',
#        'Дания - Австрия - Ирландия - Финляндия - Норвегия - Швеция - Нидерланды',
#        'Франция-США', 'Канада - Южная Корея', 'Франция - Канада',
#        'Испания - США', 'Малайзия', 'Киргизия', 'Грузия', 'США-Канада',
#        'Франция - Дания - Швеция - КНР', 'Аргентина - Франция - Испания',
#        'Франция-Бельгия', 'Россия-Кипр', 'Грузия-Франция', 'США, Россия',
#        'Франция - Бельгия - Испания', 'Аргентина - Бразилия',
#        'Россия - Италия', 'Республика Армения',
#        'Канада - США - Германия - Франция',
#        'Испания, Франция, Великобритания, Дания, Бельгия, Германия',
#        'Франция, Германия', 'Россия, Италия', 'Бразилия - К;анада',
#        'Ирландия', 'Дания - Латвия - Россия - США',
#        'Грузия - Россия - Украина - Хорватия - Германия',
#        'Испания - Аргентина',
#        'Испания - Франция - Нидерланды - Германия - Бельгия - Великобритания - Канада',
#        'Люксембург - Бельгия - Франция', 'Франция - Бразилия',
#        'Украина - Германия - Латвия - Эстония', 'Венгрия',
#        'Великобритания - Люксембург',
#        'Германия - США - Великобритания - Израиль',
#        'Великобритания - США - Германия - Бельгия',
#        'Финляндия - Швеция - Германия',
#        'Великобритания - США - Канада - Нидерланды - Франция',
#        'Италия - Аргентина - Словения ', 'Россия-Словакия-Чехия',
#        'Ирландия, Великобритания', 'Польша - Италия - Россия',
#        'Италия - Франция', 'Япония - КНР - Южная Корея', 'Португалия',
#        'Армения-Россия', 'Корея', 'США-Россия',
#        'Финляндия - Швеция - Норвегия',
#        'Румыния, ЮАР, Иран, Франция, Канада, Великобритания',
#        'Республика Корея',
#        'Великобритания - Франция - Италия - Индия - Дания - КНР - Бангладеш - Камбоджа - Гаити - Уганда',
#        'Германия - Великобритания - США', 'Австралия - Германия',
#        'Великобритания - Испания - Италия - Латвия - Франция - Эстония',
#        'Франция - Германия - Литва - Нидерланды - Россия',
#        'Норвегия - Швеция - Россия', 'Аргентина - Испания',
#        'Германия - Люксембург - Бельгия',
#        'Франция - Германия - Турция - Катар', 'Польша - Ирландия',
#        'Швейцария - Франция', 'Уругвай - Колумбия',
#        'Испания - Германия - Нидерланды', 'Бразилия', 'Канада-США',
#        'Нидерланды - Бельгия - Болгария', 'Франция, Бельгия',
#        'Болгария - США',
#        'Испания - Швейцария - Великобритания - Германия - Новая Зеландия - Нидерланды - Канада',
#        'Германия - Австрия', 'Италия - Франция - Швейцария',
#        'Ирландия - Великобритания - Франция - США - Германия - Нидерланды',
#        'Франция - Германия - Швеция - США - Чехия - Словакия - Великобритания - Нидерланды',
#        'Япония, Великобритания', 'Аргентина', 'Швеция - Дания',
#        'Италия-Франция',
#        'Франция - Бельгия - Великобритания - Испания - Германия - США',
#        'Великобритания, Нидерланды, Польша, Швейцария, Франция',
#        'США - Гонконг', 'Швеция, Норвегия, Финляндия, Франция',
#        'Ирландия - Великобритания - Франция - США',
#        'США - Нидерланды - Финляндия - Великобритания - Италия',
#        'Венгрия - Германия - Швеция', 'Россия, Германия',
#        'Великобритания - Италия - Испания',
#        'США - Канада - Франция - Индия',
#        'Великобритания - Франция - Австрия - Швеция',
#        'Уругвай - Аргентина - Испания', 'Великобритания - Ирландия',
#        'Великобритания - Исландия - Испания - Швейцария - США',
#        'Греция - Россия',
#        'Норвегия - Азербайджан - Россия - Колумбия - Великобритания - Венгрия - Румыния - Франция - Грузия',
#        'Швейцария - КНР - США - Россия - Республика Корея - Великобритания',
#        'США - Франция - Канада - Великобритания', 'Франция - Нидерланды',
#        'КНР - Франция', 'Дания - Исландия', 'Мексика', 'Китай',
#        'Франция - Сенегал - Бельгия', 'Германия - Австрия - Франция',
#        'Швеция', 'Франция, Новая Зеландия',
#        'Австрия, Великобритания, Германия', 'Киргизия-Россия',
#        'Норвегия, Швеция, Дания', 'Франция - Финляндия',
#        'Австралия - Ирландия', 'Украина - Нидерланды',
#        'США - Пуэрто-Рико - Франция ', 'Португалия, Франция, Польша, США',
#        'Индия - Мексика',
#        'Франция - Канада - Н.Зеландия - США - Нидерланды - Германия - Швеция - Россия',
#        'Исландия', 'CША', 'КНР - США', 'Швеция - Норвегия',
#        'Великобритания - Новая Зеландия', 'Грузия - Украина',
#        'Франция-Германия', 'Франция - Чехия - Бельгия',
#        'Нидерланды - Бельгия - Люксембург',
#        'Израиль - Германия - Франция - Швейцария',
#        'Мексика, Франция, Германия, Дания, Швеция', 'Финляндия, Латвия',
#        'Иран ', 'Великобритания-Германия-Канада-ЮАР',
#        'США - Канада - Россия - Франция - Чили - Ирландия',
#        'Швейцария - Израиль - Франция - Великобритания',
#        'Россия, Германия, Великобритания',
#        'Великобритания, Франция, Бельгия', 'Финляндия - Германия',
#        'Канада - Мексика', 'Латвия - Россия',
#        'Испания-Франция-Греция-Индия-США-Россия-Великобритания',
#        'Швеция - Дания - Финляндия',
#        'Великобритания - Испания - Германия',
#        'Бразилия, Уругвай, Дания, Норвегия, Чили, Швеция',
#        'США - Великобритания - Италия - Израиль - Сербия - Индия',
#        'Великобритания - Испания - Непал - Индия - Венгрия - Гонконг - Германия - Дания - Бахрейн',
#        'Нидерланды - США - Германия - Канада - Франция - Ирландия - Великобритания',
#        'Франция - Дания', 'Франция - Великобритания', 'Бельгия, Канада',
#        'США - Франция - Канада - Германия - Австралия - Индия',
#        'Франция -Бельгия', 'Франция - США - Бельгия',
#        'Великобритания - Канада', 'Польша', 'Канада - Германия',
#        'Нидерланды - Бельгия - Германия - Ирландия', 'Италия, Испания',
#        'Пакистан', 'Великобритания - Франция - Венгрия',
#        'Германия - Бельгия', 'США - Россия',
#        'Великобритания - Чехия - Франция', 'Великобритания, Франция',
#        'Великобритания - США - Германия - Канада - Австралия',
#        'Италия-Швейцария-Франция-Германия ', 'КНР - Гонконг',
#        'Франция - Германия - Бельгия',
#        'Германия - Швейцария - Франция - Южная Корея - США',
#        'Германия - Бельгия - Великобритания',
#        'Великобритания - США - Канада',
#        'Испания - Франция - США - Великобритания - Бельгия',
#        'Бельгия - Нидерланды - Франция',
#        'Бразилия - Португалия - Франция', 'Швейцария - Великобритания',
#        'Германия, Франция, США', 'Италия - Швейцария - Германия',
#        'Италия - США',
#        'Германия - Дания - Испания - Швеция - Канада - Эстония - Франция',
#        'Испания - Франция', 'Германия - Канада',
#        'Великобритания - Аргентина - США - Франция - Россия - Испания',
#        'Великобритания - Франция - Бельгия',
#        'Франция - Испания - Дания - Венгрия - Швейцария',
#        'Италия - Фрация - Бразилия - Германия', 'Венесуэла',
#        'США - Германия', 'Индонезия',
#        'Франция - Швеция - Дания - Норвегия', 'Иран, Франция',
#        'Россия, Германия, Казахстан, Польша, Китай',
#        'Великобритания - Австралия - США', 'Италия, Франция',
#        'Израиль - Франция - Германия - Палестина - США - Австрия - Великобритания',
#        'США - Чили', 'Россия, Испания', 'Франция, Бельгия, Люксембург',
#        'Канада - США - Нидерланды - Великобритания - Аргентина',
#        'Франция - Бельгия - Великобритания - США - Нидерланды - Канада',
#        'Нидерланды, Бельгия', 'Чехия - Словакия - Хорватия',
#        'Германия - Франция',
#        'Дания - Франция - Италия - Бельгия - Нидерланды',
#        'Франция - США - Норвегия - Дания', 'Канада-Германия',
#        'Колумбия - США', 'США - Дания', 'США - Италия',
#        'Франция - Польша - Бельгия',
#        'Дания - Канада - Швеция - Франция - Германия - Великобритания - США',
#        'Австрия - Германия', 'Турция - США', 'Германия, Франция',
#        'Китай-Гонконг', 'США - Болгария - Мексика', 'Россия, Украина',
#        'Россия, Армения', 'Великобритания-Франция',
#        'США - Колумбия - Испания', 'Аргентина-Испания',
#        'Франция - Италия', 'Франция - Германия - Нидерланды',
#        'Германия-Швеция', 'Великобритания - КНР',
#        'Франция - Бельгия - Канада', 'США - Китай',
#        'Испания, Ирландия, Бельгия, Франция',
#        'Австралия - Великобритания - Бельгия - Индия',
#        'Республика Беларусь, Германия, США, Россия', 'Испания-Аргентина',
#        'КНР - Канада - США', 'Таиланд - США', 'Россия, Украина, Польша',
#        'Швеция - Германия - Франция - Норвегия', 'Россия,  Испания',
#        'Россия, Франция, Латвия', 'Франция - Бельгия - Япония',
#        'Дания, Норвегия, Венгрия, Чехия',
#        'Великобритания - Франция - США', 'Новая Зеландия - КНР',
#        'Россия, Украина, Республика Беларусь, Литва',
#        'Франция - Бразилия - Италия',
#        'Великобритания - Россия - Украина - США',
#        'Пуэрто-Рико, Великобритания, США', 'Мексика - США',
#        'Великобритания, США',
#        'Нидерланды - Франция - Германия - Бельгия - Швеция - Великобритания',
#        'Франция - Германия - США', 'Чехия', 'Финляндия - Польша',
#        'Китай, Канада, США', 'Германия - Люксембург - Франция',
#        'Аргентина, Испания', 'США - ЮАР - Гонконг',
#        'Франция - Бельгия - Чехия', 'Франция - Германия - Австрия',
#        'Италия-Великобритания', 'Нидерланды - Великобритания - Бельгия',
#        'Польша - Франция - Испания - Бразилия - Швеция',
#        'США, Великобритания, Люксембург',
#        'Великобритания, Германия, Дания, США', 'Бразилия - Испания',
#        'Франция - Люксембург', 'Израиль',
#        'Ирландия - Великобритания - Канада', 'Испания-Колумбия',
#        'США-Франция-Ирландия',
#        'Франция - Великобритания - Камбоджа - США - КНР',
#        'Германия - Франция -  Польша - Турция - Канада - Италия - Россия ',
#        'КНР-США', 'Франция - Израиль - Германия', 'США, Украина',
#        'Германия - США - Франция - Испания', 'Ливан-США',
#        'Княжество Андорра - Украина', 'США-Ирландия',
#        'Германия - Австралия', 'Болгария', 'Франция-Бельгия-Канада',
#        'Перу', 'Россия - Франция - Великобритания - Латвия',
#        'Великобритания, Швеция, США', 'Бельгия, Великобритания, США',
#        'Великобритания, Австралия', 'Испания, Франция, Италия',
#        'Германия - Франция - Великобритания - Польша - США',
#        'США-Великобритания', 'Россия-Ирландия',
#        'США - Германия - Великобритания', 'Канада, Великобритания',
#        'Швеция - Германия - Франция - Дания',
#        'США - Великобритания - Новая Зеландия', 'Австралия-Ирландия',
#        'Испания - Бельгия - Франция - Португалия - Великобритания',
#        'Польша - Франция - Великобритания', 'Франция -  Бельгия',
#        'Ирландия-Нидерланды-Франция-США-Великобритания',
#        'Новая Зеландия - США', 'Великобритания - Канада - США',
#        'Германия - Австрия - Ирландия', 'Китай, США',
#        'Чехия-Великобритания-США', 'Франция - КНР',
#        'Финляндия - Великобритания - Германия',
#        'США - Великобритания - Германия - Бельгия - Дания',
#        'Испания - Великобритания - Франция',
#        'Германия - Франция - Бельгия', 'Сербия - Великобритания - США',
#        'Испания-Канада', 'Великобритания - Ирландия - США ',
#        'Франция - Македония', 'Великобритания - Мексика - США',
#        'Канада- Испания', 'Аргентина - Испания - Уругвай',
#        'Великобритания - США - Россия', 'Италия-США', 'ЮАР - США',
#        'Франция - Испания - Румыния - США - Бельгия',
#        'Франция - Дания - США', 'Мексика - Чили', 'КНР - Сингапур',
#        'Великобритания, США, Испания',
#        'Россия, Латвия, Чешская Республика',
#        'США, Великобритания, Франция', 'Мексика - Тайвань - США',
#        'Франция - Германия - Италия', 'Великобритания - США - Германия',
#        'США - Франция - Германия', 'Германия, Австралия', 'Германия, США',
#        'США-Колумбия', 'США - КНР - Индия - Ю.Корея',
#        'Великобритания - Франция - Германия - США',
#        'Бельгия - Франция - Люксембург', 'Чили - Франция - США',
#        'Великобритания-США', 'Китай-Гонконг-США',
#        'США - Австралия - Индия', 'Италия-Франция-Великобритания',
#        'Великобритания - Гонконг - Венгрия - США - Ирландия',
#        'Швейцария, Великобритания, Франция, США, Ирландия',
#        'Ирландия - США', 'Испания - США - Великобритания - Канада',
#        'Австралия-Турция-США', 'Чехия - Испания - США',
#        'США - Великобритания - Швейцария - Франция', 'Индия - КНР',
#        'Сингапур - Великобритания - Индонезия - Канада - США',
#        'Бельгия - США', 'Великобритания-США-Франция',
#        'Канада, США, Норвегия', 'Германия, Бельгия',
#        'Великобритания, Южная Корея, Канада, США, Индия, Китай, Япония',
#        'США, Франция', 'Великобритания - Польша', 'Исландия, Бельгия',
#        'США, Гонконг ', 'Австралия, США',
#        'Великобритания - Германия - Нидерланды - Дания',
#        'Великобритания - Румыния',
#        'Италия - Франция - Швейцария - Великобритания', 'Индия - США',
#        'США - Швеция', 'Австралия - Колумбия',
#        'Франция - Канада - Бельгия', 'Великобритания - Россия - КНР',
#        'Индия - Великобритания', 'Франция, Люксембург, Бельгия',
#        'Испания - Аргентина - Индия - США', 'ОАЭ - США',
#        'Испания - Болгария - США', 'Бельгия - Люксембург', 'Франция-КНР',
#        'Канада - Испания', 'США - Германия - Франция',
#        'Германия - Бельгия - Люксембург - Ирландия',
#        'Великобритания - Франция - Бельгия - США', 'США, Великобритания',
#        'Дания - Франция - Германия - Швеция',
#        'Канада, США, Каймановы острова', 'КНР, США',
#        'Ирландия - Великобритания - США',
#        'США - Россия - Польша - Германия - Пуэрто Рико',
#        'Германия - Бельгия - Люксембург - Норвегия',
#        'Германия - Великобритания', 'Россия, Франция, Германия, Бельгия',
#        'Великобритания, Канада', 'Германия - Люксембург - Дания',
#        'Россия-США-Канада-Люксембург', 'Бельгия - Франция',
#        'Норвегия - США', 'США - Великобритания - Болгария',
#        'Канада-Южная Корея-США',
#        'США - Великобритания - Германия - - Швеция - Канада',
#        'США - Великобритания - Швеция', 'США - Канада - КНР',
#        'Франция-Китай', 'США - Великобритания - Франция',
#        'КНР, Индия, Гонконг, США',
#        'США - Ирландия - Великобритания - Франция',
#        'Дания, Канада, Норвегия, Австралия, США', 'США - ЮАР',
#        'США - Испания', 'КНР - США ', 'Россия, Сербия',
#        'Великобритания - Нидерланды - Франция - США',
#        'Бразилия - США - КНР ',
#        'США - Франция - Германия - Канада - Австралия ', 'Россия-Китай',
#        'США - Великобритания - Канада', 'США - Германия - КНР',
#        'США - Австралия - Новая Зеландия - Великобритания',
#        'США - Мексика', 'Россия-Украина', 'США, Япония',
#        'США-Великобритания-Австралия', 'США - Финляндия', 'США- Ю.Корея',
#        'США - Гонконг - КНР ', 'США - Вьетнам',
#        'США - Великобритания - Австралия', 'США - Канада - Аргентина',
#        'Великобритания, Канада, США', 'США - Мальта',
#        'США - Великобритания - Япония',
#        'США - Великобритания - Франция - Гонконг',
#        'США - Бельгия - Великобритания', 'США - Великобритания - Испания',
#        'США - Великобритания - Канада - КНР',
#        'США - Канада - Япония - КНР', 'США, Франция, Япония',
#        'СССР, Венгрия', 'Германия-Великобритания',
#        'Великобритания - Италия', 'Чехословакия',
#        'США - Франция - Турция', 'Канада - Франция - Испания',
#        'Франция - Мексика - США', 'СССР, Швеция',
#        'Великобритания-США-Германия-КНР', 'СССР, Италия', 'Гонконг, КНР',
#        'США - Япония - Франция - Великобритания',
#        'Гонконг - Сингапур - Таиланд - Великобритания',
#        'Франция - Италия - Великобритания - США',
#        'Ирландия-Великобритания-Германия',
#        'США-Франция-Великобритания-Австрия',
#        'США - Ирландия - Великобритания',
#        'Люксембург - Нидерланды - Испания - Великобритания - США - Италия',
#        'США - Великобритания - Чехия', 'Великобритания - Германия - США',
#        'США - Франция - Великобритания', 'СССР, Польша',
#        'Франция - Испания', 'Германия - Италия - США',
#        'Дания - Швейцария - Бельгия - Франция',
#        'Франция - Австрия - Германия - Италия - США',
#        'США - Канада - Германия', 'Россия - Казахстан', 'США - ОАЭ',
#        'США - Франция - Испания - Великобритания',
#        'США-Италия-Испания-Аргентина', 'Франция - Италия - Швейцария',
#        'Германия - Великобритания - Австрия', 'США - Индия - ОАЭ',
#        'Германия-Канада-Великобритания-Швейцария-Франция', 'Чили',
#        'Португалия - Франция', 'Исландия-Ирландия-Германия',
#        'США-Индонезия', 'Мексика - Испания - Дания - США',
#        'США - Венгрия - Великобритания', 'Бельгия-Франция-Италия',
#        'Чехия - Германия', 'США-Нидерланды', 'США-Франция-Испания',
#        'Швеция-Франция-Дания', 'Германия-Франция-Польша',
#        'Франция-Великобритания - Германия',
#        'США - Бразилия - Франция - Австралия - Великобритания - Германия',
#        'Германия-Австрия', 'Германия-Италия- Шри-Ланка',
#        'Великобритания - Испания',
#        'США - Великобритания - Канада - Швеция',
#        'Босния и Герцеговина - Франция - Великобритания - Германия - Словения - Бельгия - Сербия',
#        'Великобритания - Франция - Италия - США',
#        'Норвегия - Швеция - Дания - Германия', 'Швейцария',
#        'Греция - Германия - Франция', 'Норвения',
#        'Австрия - Германия - Франция',
#        'Великобритания - Франция - Бельгия - Италия',
#        'Грузия - Франция - Люксембург',
#        'США - Франция - Великобритания - Бразилия ', 'Мексика - Франция',
#        'США - Германия - Гонконг - Сингапур',
#        'Финляндия - Австрия - Россия', 'Испания - Куба',
#        'Великобритания - ЮАР',
#        'Бразилия - Германия - Порртугалия - Франция ', 'Франция-Испания',
#        'Испания - Канада - Япония', 'Швеция-Куба',
#        'США-Великобритания-Ирландия', 'Испания - Канада',
#        'Япония-Великобритания', 'Финляндия - Франция - Германия',
#        'Мексика - Франция - Нидерланды - Германия',
#        'США-Великобритания-Индия', 'США-Канада-Бельгия',
#        'Республика Узбекистан', 'Италия ', 'Турция',
#        'Сербия - Словения - Хорватия - Черногория - Македония',
#        'Великобритания - Нидерланды - Франция - Хорватия',
#        'Япония - Франция - США - Южная Корея - Турция',
#        'Израиль - Франция', 'США - Великобритания ',
#        'Франция - Люксембург - Бельгия',
#        'Бельгия - Люксембург - Франция - Швейцария', 'Норвегия - Швеция',
#        'КНР - Гонконг - США', 'США - Сингапур - Малайзия - Индонезия',
#        'Германия - Россия',
#        'Франция - Люксембург - Германия - Бельгия - Швейцария - Великобритания ',
#        'США - Швейцария - Франция', 'Канада-ЮАР', 'Франция - Россия',
#        'Германия - Финляндия - Австралия', 'Германия - Франция - Австрия',
#        'Франция-Индия', 'Республика Беларусь',
#        'Великобритания - Австрия - Франция - США',
#        'Австрия-Германия-Франция',
#        'Дания - Швеция - Италия - Франция - Германия',
#        'Франция-Великобритания-Чехия', 'Румыния - Франция - Бельгия',
#        'Израиль - Германия - Польша - Бельгия - Франция - Люксембург',
#        'Россия, Германия, Франция, Бельгия', 'Франция - Португалия',
#        'Великобритания - Пуэрто-Рико', 'СССР, ФРГ, Западный Берлин',
#        'Франция - Австрия', 'Бельгия-Нидерланды',
#        'Канада - Франция - США - ОАЭ - Великобритания',
#        'США - Австралия - Франция', 'Исландия - Финляндия',
#        'Россия-Польша-Голландия-Словакия', 'Дания - Германия - Швеция',
#        'США-Мальта', 'США -Германия', 'США - Великобритания - Ирландия',
#        'США - Украина',
#        'США - Финляндия - Испания - Великобритания - Франция',
#        'Австралия-Великобритания',
#        'США - Канада - Афганистан - Бельгия - Франция',
#        'США - Великобритания - Германия - Новая Зеландия - Бельгия - Франция',
#        'Ирландия - Финляндия - Бельгия - Великобритания - США - Швейцария',
#        'США - Франция - Бельгия - Италия', 'Франция - Ирландия - Швеция',
#        'Азербайджан-Россия', 'Чили - Испания', 'Франция - Швейцария',
#        'Парагвай', 'США - Канада - Великобритания',
#        'Уругвай-Мексика-Германия ',
#        'Германия - Аргентина - Нидерланды - Чили',
#        'США - Канада - Индонезия', 'Армения - Казахстан', 'Финляндия',
#        'Бельгия - Испания - Канада - Нидерланды',
#        'Мексика - Эквадор - Канада - США - Франция - Малайзия - Италия - Аргентина - Германия - Индия  ',
#        'Япония - Великобритания - Франция', 'Франция-Польша',
#        'Россия-Азербайджан',
#        'США - Нидерланды - Бельгия - Венгрия - Греция - Канада',
#        'Германия - Франция - Люксембург',
#        'Великобритания - США - Франция', 'США - Австралия - Дания',
#        'Бельгия-Франция', 'США-Мексика', 'СЩА',
#        'США - Испания - Болгария', 'Армения - Германия',
#        'Швеция - Германия', 'СССР, Венгрия, ЧССР, ГДР',
#        'Бельгия - Германия - Люксембург', 'СССР  ', ' СССР ',
#        'Бразилия - США', 'Франция - Чили',
#        'Франция - США - Великобритания - Колумбия - Бельгия - Россия',
#        'СССР   ', 'Россия - Республика Кипр', ' СССР   ', 'СССР     ',
#        'Ирландия, Канада',
#        'Япония - Великобритания - Швейцария - Ирландия - Дания - Франция - Польша - Австралия - Канада  ',
#        'Великобритания - Франция - Республика Кипр - Швейцария - США - Сербия',
#        'Норвегия - Исландия - США - Великобритания ', 'Мексика - Испания',
#        'США - Чехия - Франция', 'Франция-Россия',
#        'Норвегия - Дания - Швеция',
#        'Россия - Эстония - Финляндия - Беларусь', 'США - Франция - ЮАР',
#        'Великобритания - США - Швейцария',
#        'Мексика - Нидерланды - Германия - Франция',
#        'США - Испания - Франция',
#        'Япония, Великобритания, Австрия, Германия, Ю.Корея',
#        'Великобритания - Ирландия - США', 'Германия - Исландия',
#        'СССР    ', 'Хорватия', 'Финляндия - Исландия - Швеция',
#        'Ирландия-Великобритания', ' СССР', 'СССР, Афганистан',
#        'СССР, Монголия',
#        'Великобритания - Нидерланды - Германия - Франция - Бельгия - Австрия ',
#        'Дания - Норвегия - Великобритания', 'СССР, Албания',
#        'Франция - Италия - Бельгия - КНР',
#        'Франция-Испания-Бельгия-Панама',
#        'США-Великобритания-Чехия-Румыния',
#        'Великобритания - США - Австралия - Ирландия - Германия - Куба - Канада',
#        'Швеция - США', 'Македония - Франция - Великобритания',
#        'Россия-США', 'Россия, Румыния', 'Россия, Республика Кипр',
#        'Грузия-Россия', 'США - Великобритания - Исландия',
#        'Великобритания - США - Канада - Бельгия - Нидерланды - Австрия - Германия',
#        'СССР, Россия', 'США - Норвегия', 'СССР, ГДР',
#        'Россия, Таджикистан', 'США-ФРГ-Россия',
#        'Россия, Грузия, Хорватия, Испания', 'СССР, ВНР', 'США - Колумбия',
#        'Великобритания - Дания', 'США - Канада - Германия - Франция',
#        'США-Канада-Франция', 'Россия-Италия', 'Китай - Гонконг',
#        'Германия-Австрия-Франция-Италия', 'США - Германия - Канада',
#        'Испания-Мексика',
#        'США - Япония - Канада - Великобритания - Германия - Франция',
#        'США -Великобритания - Австралия',
#        'Израиль - Франция - Великобритания - Германия',
#        'Россия - Болгария', 'Германия-Канада-Франция-Бельгия',
#        'Германия-Кения', 'Франция - Монако', 'Австрия-Франция-Германия',
#        'Румыния', 'США-Великобритания-Франция', 'Канада-Бразилия-Япония',
#        'Германия - Дания - Норвегия', 'СССР - Италия',
#        'СССР - ГДР - Польша - Италия',
#        'США - Испания - Франция - Великобритания', 'Мексика-Аргентина',
#        'Германия - Великобритания - Италия - Испания',
#        'Франция-Германия-Великобритания', 'Россия - Германия - Швейцария',
#        'Голландия', 'Швейцария-Франция', 'Франция - Испания - Тайвань',
#        'США-Южная Корея-Новая Зеландия',
#        'Великобритания-Франция-Германия', 'Франция-Германия-Италия',
#        'Швеция-Финляндия-Франция-Норвегия', 'Франция-Италия',
#        'Германия-Израиль', 'Швеция - Германия - Дания - Норвегия',
#        'Франция-Гонконг-Ирландия', 'Эстония', 'Литва-Россия-Украина',
#        'Великобритания - Австрия - Германия', 'Испания - Мальта',
#        'Франция-Россия-Румыния-Италия-Бельгия', 'Испания - Мексика',
#        'США-Аргентина', 'Великобритания ', 'Израиль-США-Франция',
#        'США - Новая Зеландия - Япония',
#        'Франция - Чехия - Великобритания', 'Россия-Польша',
#        'Германия-Франция-Великобритания', 'США-Германия-Канада',
#        'США-Гонконг-Китай', 'США - Великобритания - Германия',
#        'США-Канада-Австралия', 'Япония-США-Франция',
#        'Франция-Испания-Германия', 'США - Хорватия - Босния-Герцеговина',
#        'Великобритания - Чехия - Франция - Италия',
#        'США - Германия - Нидерланды', 'Германия - Франция - Канада',
#        'Франция-Грузия-Германия-Россия-Украина-Бельгия', 'Россия - США',
#        'Франция - Италия - Иран', 'Россия - Азербайджан', 'Греция',
#        'Дания - США', 'США-Великобритания-Новая Зеландия',
#        'США-Германия-Австралия', 'США-Канада-Италия',
#        'США - Япония - Германия', 'Австралия-США',
#        'Франция - Великобритания - Багамские острова - США',
#        'Швейцария - Люксембург', 'Швейцария - Австрия',
#        'Германия - Швейцария', 'Швейцария-Австрия', 'Нидерланды - Россия',
#        'Швеция-Франция', 'Франция-Украина', 'Германия-Украина-Нидерланды',
#        'Италия-Швейцария', 'Канада - Италия',
#        'США - Объединенные Арабские Эмираты', 'США-Венгрия',
#        'Россия - Германия - Украина', 'США - Австралия - Мексика',
#        'Литва - Венгрия',
#        'США - Германия - Франция - Великобритания - Канада ',
#        'Бельгия - Германия - Люксембург - Франция', 'Италия - Канада',
#        'США-Италия-Греция', 'Германия - США - Великобритания - Ирландия',
#        'Великобритания - Франция - Германия',
#        'Германия - Нидерланды - ЮАР',
#        'США-Япония-Германия-Великобритания-Нидерланды',
#        'США-Япония-Германия-Великобритания',
#        'Таиланд-Великобритания-Франция-Германия-Испания-Нидерланды',
#        'Германия-Италия-Швейцария',
#        'Дания - Швеция - Великобритания - Франция - Германия - Нидерланды - Норвегия - Финляндия',
#        'Франция - Великобритания - Нидерланды - Люксембург',
#        'Нидерланды-Великобритания-Франция-Италия-Япония',
#        'Финляндия-Дания-Германия-Ирландия', 'Италия - Франция - Германия',
#        'Австрия - Люксембург', 'Монголия', 'США - Германия - Япония',
#        'СССР, ФРГ', 'Франция-Германия-Австрия',
#        'Бельгия-Германия-Канада-Франция-США-Великобритания',
#        'Великобритания, Новая Зеландия', 'США - Пуэрто Рико',
#        'Россия, Нидерланды, Финляндия', 'Италия, Франция, Германия',
#        'Россия, Польша, Финляндия', 'Германия, Франция, Великобритания',
#        'Дания, Швеция, Великобритания, Франция, Германия, Норвегия, Финляндия, Нидерланды, Италия',
#        'Канада, Франция, Италия, Швейцария, США', 'США, Индия',
#        'Россия-Беларусь', 'Россия, Австрия',
#        'Великобритания - Япония - США', 'Япония - США',
#        'Франция - Россия - Швейцария - Румыния - Венгрия',
#        'Таиланд - КНР - США', 'Великобритания-Франция-Италия',
#        'Великобритания - Израиль',
#        'Великобритания - Норвегия - Кения - Хорватия',
#        'США - Бразилия - Великобритания - Канада', 'Австралия, Канада',
#        'Кения, Германия', 'Нидерланды, Бельгия, Люксембург', 'Колумбия',
#        'Латвия - Франция', 'Швеция, Франция, Великобритания',
#        'США, Великобритания, Ирландия, Люксембург', 'Япония, США',
#        'Канада, США', 'Республика Кипр - Россия', 'Россия - Грузия',
#        'Италия, Германия', 'Республика Кипр, Россия', 'Израиль, Украина',
#        'Франция, Канада', 'США, Германия', '2019',
#        'Великобритания, Япония, США', 'Сша, Канада', 'США, Канада',
#        'Норвегия - Нидерланды', 'Италия - Бельгия - Франция',
#        'Россия, Бельгия, Финляндия', 'Франция, Норвегия',
#        'Канада - Норвегия', 'Республика Кипр-Россия', 'Германия, Россия',
#        'Дания, Норвегия, Швеция, Исландия',
#        'Республика Кипр, США, Россия'], dtype=object)

# %%
clean_data['production_country'].value_counts()
# Out:
# Россия                                     1814
# США                                        1785
# СССР                                        345
# Франция                                     278
# Великобритания                              241
#                                            ...
# КНР - США                                     1
# Германия-Австрия-Франция-Италия               1
# Италия, Испания                               1
# Дания, Канада, Норвегия, Австралия, США       1
# Турция                                        1
# Name: production_country, Length: 950, dtype: int64

# %%
# сделаем универсальные разделители
clean_data['production_country'] = clean_data['production_country'].str.replace(' - ', '-')
clean_data['production_country'] = clean_data['production_country'].str.replace(', ', ',')
clean_data['production_country'] = clean_data['production_country'].str.replace('-', ',')
clean_data['production_country'] = clean_data['production_country'].str.replace(',', ', ')

clean_data['production_country'].value_counts()
# Out:
# Россия                                              1814
# США                                                 1785
# СССР                                                 345
# Франция                                              278
# Великобритания                                       241
#                                                     ...
# Франция, Бразилия                                      1
# Сингапур, Великобритания, Индонезия, Канада, США       1
# Германия, Люксембург, Бельгия                          1
# Великобритания, США, Германия, КНР                     1
# Франция, Перу                                          1
# Name: production_country, Length: 835, dtype: int64

# %%
clean_data['producer'].unique()
# Out:
# array(['Эммануэль Жаклин, Павел Солк, Филипп Херинг',
#        'Такафуми Ватанабэ, Такуя Ито, Сэйдзи Окуда, Юитиро Сайто, Нодзому Такахаси ',
#        'Хайно Декерт', ..., 'ВГИК',
#        'Джефф Боулер, Дэниэл Гродник, Луильо Руис, Брэт Саксон, Кирк Шоу',
#        'Дженнифер Додж'], dtype=object)

# %%
clean_data['producer'].value_counts()
# Out:
# unknown                                                                                                                                        559
# П.Смирнов                                                                                                                                       67
# Олег Кузовков, Дмитрий Ловейко, Марина Ратина                                                                                                   28
# С.Сельянов                                                                                                                                      18
# Д.Ловейко, О.Кузовков                                                                                                                           16
#                                                                                                                                               ...
# В.Малышев, Ю.Беленький                                                                                                                           1
# Г.Васильев,  М.Мэннис, И.Попов, А.Златопольский, С.Сельянов, А.Боярский, В.Сотсков, Т.Цыварёва, В.Воля, Е.Головин, А.Сметанкин, А.Полетаева      1
# Курбан Кассам, Батист Планше, Клаудио Чеа                                                                                                        1
# Джафар Панахи                                                                                                                                    1
# Хлинюр Палмасон, Джулия Вальтерсдорф Хансен                                                                                                      1
# Name: producer, Length: 5350, dtype: int64

# %%
clean_data['director'].unique()
# Out:
# array(['Ариэль Зейтун', 'Мамору Хосода', 'Сергей Лозница', ...,
#        'Ник Пауэлл', 'А.Беляев', 'И.Трусов'], dtype=object)

# %%
clean_data['director'].value_counts()
# Out:
# О.Семёнова                                          47
# Д.Червяцов                                          16
# Вуди Аллен                                          13
# Стивен Содерберг                                    12
# О.Семёнова                                          12
#                                                     ..
# Матье Рэтхи                                          1
# Айк Кбеян                                            1
# Р.Шарафутдинов, Е.Куркова, М.Соснина, Р.Синкевич     1
# Стивен Гэган                                         1
# Т.Джураев                                            1
# Name: director, Length: 4812, dtype: int64

# %%
clean_data['age_restriction'].value_counts()
# Out:
# «16+» - для детей старше 16 лет           2526
# «12+» - для детей старше 12 лет           1495
# «18+» - запрещено для детей               1444
# «0+» - для любой зрительской аудитории     749
# «6+» - для детей старше 6 лет              609
# Name: age_restriction, dtype: int64

# %%
clean_data['genres'].unique()
# Out:
# array(['драма,мелодрама,приключения', 'аниме,мультфильм,фантастика',
#        'драма,военный,история', 'комедия,мелодрама',
#        'мюзикл,драма,мелодрама', 'unknown', 'драма',
#        'мелодрама,комедия,драма', 'драма,мелодрама,биография',
#        'аниме,мультфильм,драма', 'драма,история', 'комедия',
#        'боевик,комедия,криминал', 'биография', 'мелодрама,комедия',
#        'драма,семейный', 'драма,биография,музыка',
#        'драма,мелодрама,история', 'фэнтези,драма,мелодрама',
#        'боевик,драма,криминал', 'комедия,приключения,семейный',
#        'мультфильм,фэнтези,комедия', 'драма,комедия',
#        'боевик,драма,приключения', 'комедия,приключения,история',
#        'боевик,триллер', 'ужасы,комедия', 'фэнтези,боевик,приключения',
#        'ужасы,триллер', 'триллер,драма,криминал',
#        'мультфильм,фэнтези,приключения', 'мультфильм,комедия,приключения',
#        'драма,мелодрама,комедия', 'комедия,приключения,музыка',
#        'комедия,приключения,вестерн', 'документальный,военный,история',
#        'фэнтези,драма,приключения', 'мультфильм,фантастика,комедия',
#        'фэнтези,приключения,комедия', 'драма,мелодрама',
#        'детский,комедия', 'приключения,детектив,мелодрама',
#        'фантастика,триллер,мелодрама', 'фэнтези,приключения',
#        'мультфильм,приключения,драма', 'боевик,комедия', 'драма,криминал',
#        'мультфильм,фэнтези,драма', 'триллер,приключения',
#        'комедия,криминал', 'фантастика,приключения,детектив',
#        'мультфильм,семейный', 'триллер,ужасы', 'ужасы,драма,триллер',
#        'триллер,детектив,драма', 'драма,боевик', 'боевик,триллер,драма',
#        'мультфильм,драма,комедия', 'драма,криминал,боевик',
#        'фэнтези,триллер,мелодрама', 'фантастика,боевик,триллер',
#        'комедия,драма', 'драма,спорт', 'фэнтези,драма,комедия',
#        'триллер,драма,приключения', 'боевик,драма',
#        'боевик,приключения,триллер', 'фэнтези,триллер,драма',
#        'мультфильм,фантастика,фэнтези', 'драма,комедия,приключения',
#        'детектив,триллер,криминал', 'комедия,мелодрама,криминал',
#        'ужасы,фантастика,триллер', 'мелодрама', 'боевик,драма,военный',
#        'мелодрама,комедия,спорт', 'мультфильм,фэнтези,боевик',
#        'мюзикл,мелодрама,комедия', 'боевик,драма,мелодрама',
#        'ужасы,фантастика,фэнтези', 'аниме,мультфильм,фэнтези',
#        'боевик,приключения', 'фэнтези,приключения,боевик',
#        'ужасы,фэнтези,боевик', 'комедия,семейный',
#        'ужасы,триллер,комедия', 'ужасы,комедия,драма', 'драма,военный',
#        'боевик,криминал', 'ужасы,триллер,детектив',
#        'фантастика,боевик,приключения', 'триллер,драма,детектив',
#        'комедия,приключения,мелодрама', 'фантастика,боевик,драма',
#        'ужасы,триллер,драма', 'боевик', 'комедия,приключения,фэнтези',
#        'комедия,мелодрама,фэнтези', 'криминал',
#        'мультфильм,комедия,семейный', 'боевик,фантастика,приключения',
#        'фантастика,триллер,драма', 'мультфильм,комедия,криминал',
#        'комедия,приключения', 'драма,детектив,приключения', 'приключения',
#        'фэнтези,боевик,ужасы', 'ужасы,триллер,мелодрама',
#        'история,спорт,драма', 'комедия,боевик,приключения',
#        'триллер,драма,мелодрама', 'ужасы,драма',
#        'документальный,короткометражка', 'история,драма,боевик',
#        'криминал,комедия,боевик', 'приключения,фантастика',
#        'мелодрама,приключения,боевик', 'боевик,триллер,криминал',
#        'фантастика,драма', 'мультфильм,приключения,семейный',
#        'ужасы,боевик,триллер', 'мультфильм,фэнтези,мелодрама',
#        'драма,комедия,семейный', 'триллер,криминал,боевик',
#        'мультфильм,боевик,комедия', 'фантастика,фэнтези,боевик',
#        'триллер,мелодрама,драма', 'триллер,драма',
#        'приключения,история,драма', 'драма,мелодрама,музыка',
#        'ужасы,фэнтези,триллер', 'мультфильм', 'драма,комедия,криминал',
#        'мультфильм,семейный,спорт', 'фэнтези,комедия,семейный',
#        'боевик,триллер,приключения', 'мультфильм,мюзикл,комедия',
#        'ужасы,боевик,фэнтези', 'боевик,триллер,комедия',
#        'фэнтези,боевик,драма', 'фэнтези,драма,детектив', 'ужасы',
#        'фильм-нуар,триллер,детектив', 'детский,приключения,комедия',
#        'фантастика,мелодрама,комедия', 'мюзикл,комедия,детский',
#        'фантастика,комедия,приключения', 'боевик,триллер,мелодрама',
#        'фантастика,фэнтези,драма', 'история', 'фэнтези,мелодрама,комедия',
#        'детский,фэнтези', 'драма,криминал,биография',
#        'приключения,боевик,триллер', 'боевик,драма,комедия',
#        'военный,драма,боевик', 'мультфильм,фэнтези', 'драма,детектив',
#        'ужасы,детектив', 'фэнтези,боевик,семейный', 'ужасы,фантастика',
#        'драма,криминал,детектив', 'драма,биография',
#        'триллер,драма,биография', 'фэнтези,семейный,мелодрама',
#        'приключения,история', 'боевик,мелодрама,комедия',
#        'боевик,триллер,детектив', 'драма,комедия,музыка', 'фэнтези',
#        'ужасы,комедия,приключения', 'мультфильм,мюзикл,фэнтези',
#        'драма,мелодрама,детектив', 'драма,семейный,биография',
#        'мелодрама,драма,музыка', 'мелодрама,драма,фэнтези',
#        'драма,вестерн', 'военный', 'семейный', 'аниме,мультфильм,ужасы',
#        'семейный,мелодрама', 'ужасы,мелодрама,детектив',
#        'мелодрама,комедия,семейный', 'криминал,комедия,драма',
#        'мультфильм,комедия,детский', 'драма,биография,история',
#        'мультфильм,фантастика,приключения', 'мультфильм,мюзикл,драма',
#        'документальный,драма,семейный', 'драма,триллер,детектив',
#        'ужасы,фантастика,боевик', 'мультфильм,приключения',
#        'боевик,фантастика', 'фантастика,комедия',
#        'боевик,приключения,история', 'боевик,комедия,приключения',
#        'комедия,драма,семейный', 'боевик,криминал,триллер',
#        'мультфильм,фэнтези,семейный', 'фэнтези,приключения,семейный',
#        'мультфильм,мелодрама,комедия', 'приключения,боевик',
#        'драма,фантастика', 'триллер,комедия,криминал',
#        'комедия,криминал,семейный', 'аниме,мультфильм,мелодрама',
#        'триллер,детектив,ужасы', 'мелодрама,фантастика,драма',
#        'приключения,биография,история', 'документальный,музыка',
#        'приключения,семейный,драма', 'детский,приключения,фантастика',
#        'военный,боевик,драма', 'мультфильм,фантастика,боевик',
#        'мультфильм,короткометражка,детский', 'история,мелодрама',
#        'приключения,семейный', 'комедия,фантастика',
#        'фэнтези,комедия,драма', 'детектив,триллер,боевик',
#        'детский,приключения,семейный', 'вестерн,криминал,триллер',
#        'драма,спорт,биография', 'детский,фэнтези,приключения',
#        'криминал,комедия,триллер', 'мультфильм,детский',
#        'мелодрама,комедия,музыка', 'спорт,драма,биография',
#        'триллер,мелодрама,комедия', 'мелодрама,драма', 'документальный',
#        'детский', 'документальный,спорт,биография',
#        'детектив,история,драма', 'фэнтези,драма', 'военный,драма',
#        'триллер,криминал,детектив', 'ужасы,фэнтези,драма',
#        'фэнтези,приключения,драма', 'аниме,мультфильм,боевик',
#        'мелодрама,фэнтези,триллер', 'документальный,ужасы',
#        'детский,семейный', 'триллер',
#        'документальный,короткометражка,семейный',
#        'документальный,приключения', 'мультфильм,приключения,комедия',
#        'драма,биография,спорт', 'документальный,биография',
#        'мультфильм,приключения,фантастика', 'короткометражка,драма',
#        'аниме,мультфильм,детектив', 'мультфильм,мюзикл,детский',
#        'фантастика,комедия,боевик', 'фэнтези,боевик',
#        'драма,детектив,криминал', 'криминал,драма', 'комедия,фэнтези',
#        'фэнтези,триллер,приключения', 'история,биография,драма',
#        'биография,драма', 'документальный,биография,спорт',
#        'комедия,криминал,драма', 'триллер,боевик',
#        'криминал,биография,комедия', 'фантастика,боевик,военный',
#        'триллер,драма,военный', 'драма,комедия,мультфильм',
#        'триллер,криминал', 'ужасы,боевик,комедия', 'драма,триллер',
#        'документальный,драма,биография', 'триллер,драма,фантастика',
#        'мультфильм,фэнтези,детский', 'мультфильм,ужасы,фантастика',
#        'мультфильм,семейный,детский', 'мюзикл,фэнтези,комедия',
#        'документальный,приключения,семейный', 'концерт,музыка',
#        'документальный,фэнтези,драма', 'комедия,ужасы',
#        'семейный,приключения,комедия', 'триллер,мелодрама',
#        'фантастика,детектив,боевик', 'документальный,комедия',
#        'мелодрама,криминал', 'комедия,музыка', 'фантастика',
#        'драма,комедия,военный', 'триллер,комедия',
#        'документальный,биография,музыка', 'концерт,музыка,документальный',
#        'история,драма,мелодрама', 'фантастика,боевик,комедия',
#        'фантастика,драма,мелодрама', 'детский,мелодрама,семейный',
#        'документальный,биография,история', 'военный,история',
#        'мелодрама,комедия,триллер', 'документальный,новости,драма',
#        'приключения,мелодрама,детектив', 'приключения,детектив,семейный',
#        'драма,музыка', 'комедия,драма,военный', 'драма,криминал,семейный',
#        'криминал,боевик,триллер', 'семейный,приключения,военный',
#        'мультфильм,история', 'документальный,драма,история',
#        'детектив,криминал,боевик', 'драма,военный,биография',
#        'ужасы,драма,мелодрама', 'ужасы,драма,вестерн', 'криминал,боевик',
#        'приключения,детский', 'фэнтези,драма,ужасы', 'комедия,триллер',
#        'фантастика,мелодрама,боевик', 'для взрослых,драма,комедия',
#        'фэнтези,комедия', 'драма,криминал,фильм-нуар',
#        'мультфильм,боевик,приключения',
#        'мультфильм,мелодрама,приключения', 'ужасы,фантастика,драма',
#        'мюзикл,боевик,драма', 'фантастика,фэнтези,комедия',
#        'драма,история,военный', 'мультфильм,семейный,драма',
#        'драма,комедия,вестерн', 'комедия,детектив',
#        'вестерн,драма,триллер', 'музыка,концерт,документальный',
#        'аниме,мультфильм,приключения', 'биография,история,драма',
#        'драма,комедия,биография', 'мелодрама,комедия,приключения',
#        'комедия,военный,музыка', 'документальный,история',
#        'триллер,драма,история', 'фэнтези,боевик,комедия',
#        'мультфильм,драма,приключения', 'мюзикл,фэнтези,семейный',
#        'фэнтези,ужасы,триллер', 'комедия,триллер,драма', 'спорт,драма',
#        'детектив', 'мультфильм,боевик,триллер',
#        'семейный,детектив,детский', 'боевик,приключения,семейный',
#        'мелодрама,приключения', 'история,детектив',
#        'вестерн,биография,драма', 'триллер,ужасы,драма',
#        'драма,мелодрама,криминал', 'драма,история,биография',
#        'музыка,концерт', 'мультфильм,приключения,фэнтези',
#        'комедия,история,драма', 'мюзикл,фэнтези,мелодрама',
#        'фантастика,боевик', 'драма,комедия,история',
#        'фэнтези,драма,фильм-нуар', 'фантастика,боевик,фэнтези',
#        'ужасы,фэнтези', 'биография,криминал,драма', 'фэнтези,семейный',
#        'комедия,приключения,детектив', 'мелодрама,драма,комедия',
#        'драма,ужасы', 'ужасы,фантастика,комедия', 'ужасы,приключения',
#        'комедия,драма,криминал', 'драма,мелодрама,военный',
#        'фантастика,драма,боевик', 'мультфильм,короткометражка,комедия',
#        'ужасы,комедия,детектив', 'мультфильм,мелодрама,драма',
#        'комедия,семейный,приключения', 'триллер,приключения,драма',
#        'криминал,боевик,комедия', 'ужасы,комедия,криминал',
#        'аниме,мультфильм,комедия', 'биография,криминал,триллер',
#        'фэнтези,комедия,приключения', 'детектив,фантастика,триллер',
#        'ужасы,фэнтези,комедия', 'комедия,мелодрама,драма',
#        'семейный,мультфильм,комедия', 'драма,комедия,детектив',
#        'боевик,вестерн,приключения', 'биография,спорт,драма',
#        'семейный,документальный', 'криминал,триллер,драма',
#        'фэнтези,триллер,детектив', 'биография,драма,военный',
#        'фэнтези,мелодрама,приключения', 'боевик,драма,биография',
#        'фантастика,фэнтези,триллер', 'комедия,биография',
#        'мультфильм,комедия', 'приключения,биография,драма',
#        'фантастика,драма,приключения', 'драма,комедия,спорт',
#        'триллер,ужасы,криминал', 'мелодрама,история',
#        'фэнтези,боевик,мелодрама', 'драма,биография,комедия',
#        'документальный,фэнтези', 'комедия,боевик,фантастика',
#        'семейный,приключения,документальный', 'военный,драма,история',
#        'боевик,триллер,фэнтези', 'ужасы,триллер,криминал',
#        'боевик,драма,вестерн', 'триллер,детектив',
#        'драма,история,детектив', 'мультфильм,семейный,фэнтези',
#        'комедия,мультфильм,фантастика', 'биография,драма,история',
#        'детектив,драма,триллер', 'военный,детектив',
#        'детектив,фильм-нуар,комедия', 'драма,приключения,семейный',
#        'история,приключения', 'фантастика,триллер',
#        'драма,комедия,триллер', 'документальный,триллер,биография',
#        'драма,спорт,комедия', 'драма,приключения,триллер',
#        'криминал,комедия', 'драма,военный,триллер', 'приключения,триллер',
#        'фантастика,приключения', 'мелодрама,триллер,история',
#        'история,драма', 'ужасы,комедия,фантастика',
#        'приключения,фантастика,драма', 'фэнтези,боевик,триллер',
#        'детектив,триллер,драма', 'мультфильм,фэнтези,история',
#        'мюзикл,мелодрама', 'фэнтези,мелодрама',
#        'фантастика,комедия,детектив', 'драма,приключения',
#        'драма,боевик,криминал', 'боевик,драма,триллер',
#        'комедия,семейный,фэнтези', 'фантастика,мелодрама',
#        'драма,спорт,история', 'комедия,мелодрама,фантастика',
#        'мюзикл,комедия,мелодрама', 'драма,триллер,биография',
#        'комедия,спорт', 'фантастика,триллер,комедия',
#        'драма,криминал,вестерн', 'спорт,мелодрама,криминал',
#        'детектив,криминал,триллер', 'биография,спорт,комедия',
#        'мелодрама,история,триллер', 'мелодрама,военный,драма',
#        'комедия,криминал,детектив', 'триллер,криминал,драма',
#        'документальный,музыка,биография', 'триллер,драма,комедия',
#        'фантастика,триллер,криминал', 'мультфильм,комедия,фантастика',
#        'мюзикл,семейный,драма', 'фантастика,триллер,приключения',
#        'ужасы,комедия,музыка', 'криминал,драма,триллер',
#        'драма,боевик,приключения', 'триллер,ужасы,мелодрама',
#        'семейный,фэнтези', 'реальное ТВ', 'фантастика,боевик,ужасы',
#        'триллер,мелодрама,детектив', 'драма,мелодрама,фэнтези',
#        'мультфильм,ужасы,комедия', 'мультфильм,биография,драма',
#        'военный,боевик,история', 'драма,фантастика,ужасы',
#        'биография,мелодрама,драма', 'мультфильм,ужасы,фэнтези',
#        'триллер,криминал,приключения', 'триллер,фэнтези',
#        'ужасы,драма,детектив', 'драма,боевик,история',
#        'музыка,мелодрама,фэнтези', 'документальный,музыка,концерт',
#        'мюзикл,фэнтези,драма', 'боевик,криминал,драма', 'ужасы,боевик',
#        'ужасы,фэнтези,детектив', 'триллер,фантастика,драма',
#        'мелодрама,детектив,комедия', 'боевик,фэнтези,драма',
#        'комедия,криминал,биография', 'биография,драма,криминал',
#        'комедия,криминал,приключения', 'детектив,фэнтези,триллер',
#        'мультфильм,приключения,военный', 'биография,музыка,мюзикл',
#        'фантастика,приключения,военный', 'комедия,музыка,драма',
#        'биография,музыка,драма', 'приключения,история,военный',
#        'триллер,ужасы,детектив', 'фэнтези,ужасы',
#        'приключения,фэнтези,семейный', 'мультфильм,семейный,комедия',
#        'комедия,детектив,приключения', 'семейный,фэнтези,комедия',
#        'триллер,комедия,ужасы', 'семейный,комедия', 'приключения,фэнтези',
#        'ужасы,фантастика,детектив', 'мелодрама,семейный,приключения',
#        'спорт,драма,комедия', 'триллер,фантастика,боевик',
#        'мелодрама,музыка,драма', 'мультфильм,приключения,детский',
#        'боевик,фантастика,триллер', 'семейный,комедия,музыка',
#        'ужасы,комедия,боевик', 'комедия,семейный,фантастика',
#        'мультфильм,короткометражка,фэнтези', 'боевик,военный,драма',
#        'ужасы,боевик,фантастика', 'фантастика,фэнтези,приключения',
#        'триллер,боевик,приключения', 'фантастика,приключения,семейный',
#        'детектив,комедия,драма', 'мультфильм,детский,приключения',
#        'биография,военный,драма', 'драма,биография,мюзикл',
#        'семейный,комедия,драма', 'детектив,приключения,драма',
#        'детектив,приключения,триллер', 'фэнтези,семейный,приключения',
#        'фантастика,фэнтези,детектив', 'приключения,триллер,биография',
#        'комедия,драма,биография', 'история,боевик,фэнтези',
#        'детектив,криминал,драма', 'приключения,вестерн,боевик',
#        'фантастика,приключения,боевик', 'драма,триллер,приключения',
#        'комедия,фэнтези,приключения', 'драма,военный,боевик',
#        'драма,мелодрама,семейный', 'мультфильм,короткометражка,мелодрама',
#        'фантастика,драма,детектив', 'мюзикл,семейный',
#        'военный,приключения,драма', 'документальный,драма',
#        'комедия,история', 'триллер,военный', 'мюзикл,комедия',
#        'военный,биография,драма', 'боевик,история,драма',
#        'драма,криминал,спорт', 'криминал,детектив,приключения',
#        'мелодрама,биография', 'фэнтези,мелодрама,драма',
#        'криминал,детектив', 'мультфильм,короткометражка,ужасы',
#        'комедия,криминал,история', 'боевик,история',
#        'приключения,детский,комедия', 'мелодрама,комедия,криминал',
#        'мюзикл,ужасы,триллер', 'детектив,триллер,ужасы',
#        'мультфильм,драма', 'мюзикл,мелодрама,фэнтези',
#        'комедия,семейный,музыка', 'комедия,фантастика,мелодрама',
#        'боевик,военный', 'боевик,драма,история',
#        'для взрослых,драма,мелодрама', 'мультфильм,боевик,детектив',
#        'мелодрама,музыка', 'драма,приключения,военный',
#        'мюзикл,комедия,приключения', 'короткометражка,драма,военный',
#        'драма,мультфильм', 'документальный,фэнтези,семейный',
#        'ужасы,комедия,фэнтези', 'приключения,драма',
#        'фантастика,боевик,криминал', 'мюзикл,драма',
#        'комедия,биография,история', 'комедия,криминал,спорт',
#        'документальный,мюзикл', 'триллер,криминал,комедия',
#        'фантастика,драма,комедия', 'комедия,драма,мелодрама',
#        'драма,приключения,биография', 'драма,фэнтези',
#        'документальный,семейный', 'фэнтези,драма,семейный',
#        'вестерн,боевик,драма', 'ужасы,мелодрама,комедия',
#        'приключения,фантастика,семейный', 'драма,приключения,фэнтези',
#        'фантастика,мультфильм,драма', 'драма,история,музыка',
#        'триллер,боевик,криминал', 'драма,фантастика,триллер',
#        'фантастика,драма,триллер', 'биография,история', 'боевик,фэнтези',
#        'документальный,комедия,история', 'триллер,драма,боевик',
#        'комедия,криминал,боевик', 'комедия,фантастика,боевик',
#        'вестерн,приключения,боевик', 'боевик,мелодрама',
#        'комедия,криминал,триллер', 'комедия,боевик,криминал',
#        'комедия,вестерн', 'короткометражка,мультфильм',
#        'фантастика,драма,ужасы', 'триллер,драма,ужасы',
#        'драма,фэнтези,история', 'комедия,драма,короткометражка',
#        'комедия,фэнтези,ужасы', 'короткометражка,комедия,криминал',
#        'фантастика,приключения,драма', 'боевик,детектив',
#        'драма,история,триллер', 'детектив,драма,криминал',
#        'музыка,приключения,концерт', 'военный,драма,комедия',
#        'фэнтези,боевик,военный', 'детектив,криминал',
#        'мелодрама,комедия,ужасы', 'драма,криминал,приключения',
#        'драма,криминал,фантастика', 'фэнтези,драма,биография',
#        'детектив,фантастика,криминал', 'ужасы,фэнтези,мелодрама',
#        'детектив,ужасы,криминал', 'драма,военный,приключения',
#        'криминал,драма,комедия', 'драма,вестерн,боевик',
#        'фантастика,триллер,детектив', 'короткометражка,биография',
#        'мультфильм,приключения,детектив',
#        'документальный,криминал,военный', 'короткометражка,музыка',
#        'триллер,детектив,криминал', 'короткометражка,мелодрама',
#        'комедия,фэнтези,мелодрама', 'аниме,мультфильм',
#        'мультфильм,короткометражка', 'мультфильм,детский,комедия',
#        'документальный,боевик,приключения', 'приключения,военный',
#        'короткометражка', 'боевик,приключения,детектив',
#        'документальный,фантастика', 'драма,спорт,семейный',
#        'фантастика,мелодрама,фэнтези', 'мюзикл,комедия,музыка',
#        'приключения,комедия,фэнтези', 'фэнтези,боевик,детектив',
#        'комедия,военный', 'драма,спорт,боевик', 'мелодрама,семейный',
#        'фантастика,боевик,детектив', 'драма,приключения,история',
#        'документальный,драма,музыка', 'фантастика,триллер,боевик',
#        'фэнтези,боевик,вестерн', 'драма,комедия,мелодрама',
#        'ужасы,фэнтези,приключения', 'триллер,фэнтези,драма',
#        'мультфильм,мюзикл,мелодрама', 'ужасы,триллер,фантастика',
#        'ужасы,комедия,семейный', 'документальный,комедия,криминал',
#        'мелодрама,детектив', 'короткометражка,боевик,драма',
#        'боевик,комедия,семейный', 'фантастика,боевик,мелодрама',
#        'драма,детектив,история', 'боевик,криминал,детектив',
#        'мелодрама,драма,боевик', 'драма,вестерн,приключения',
#        'драма,приключения,мелодрама', 'фэнтези,боевик,криминал',
#        'фантастика,комедия,семейный', 'семейный,спорт,боевик',
#        'триллер,биография,драма', 'ужасы,драма,комедия',
#        'мультфильм,фэнтези,триллер', 'мюзикл', 'боевик,спорт,драма',
#        'документальный,ужасы,боевик', 'фантастика,боевик,семейный',
#        'ужасы,боевик,криминал', 'детектив,триллер',
#        'драма,семейный,комедия', 'драма,криминал,история',
#        'драма,комедия,фантастика', 'комедия,приключения,спорт',
#        'семейный,приключения', 'детектив,мелодрама,фэнтези',
#        'боевик,военный,история', 'триллер,мелодрама,криминал',
#        'военный,история,драма', 'фантастика,детектив,фэнтези',
#        'мультфильм,короткометражка,мюзикл', 'мультфильм,детский,семейный',
#        'документальный,драма,комедия', 'комедия,приключения,криминал',
#        'документальный,семейный,музыка', 'драма,мелодрама,триллер',
#        'документальный,спорт', 'биография,документальный',
#        'ужасы,фантастика,мелодрама', 'детектив,комедия',
#        'история,биография,военный', 'криминал,мелодрама',
#        'детектив,мелодрама', 'драма,комедия,ужасы',
#        'фантастика,драма,криминал', 'короткометражка,фантастика',
#        'детский,мультфильм,приключения', 'ужасы,триллер,приключения',
#        'фэнтези,комедия,детектив', 'аниме,мультфильм,короткометражка',
#        'приключения,драма,фантастика', 'комедия,фэнтези,криминал',
#        'биография,спорт,история', 'детектив,боевик,история',
#        'фэнтези,комедия,криминал', 'ужасы,драма,военный',
#        'история,криминал', 'драма,триллер,криминал',
#        'короткометражка,драма,триллер', 'документальный,военный,драма',
#        'мелодрама,история,драма'], dtype=object)

# %%
clean_data['genres'].value_counts()
# Out:
# unknown                           968
# драма                             454
# комедия                           330
# мелодрама,комедия                 181
# драма,мелодрама                   171
#                                  ...
# боевик,военный,история              1
# приключения,история,драма           1
# история                             1
# мультфильм,приключения,военный      1
# детектив,драма,триллер              1
# Name: genres, Length: 743, dtype: int64

# %% [markdown]
# Общая проблема почти во всех категориальных столбцах:
# - перечисления нексольких объектов в разном порядке
# - также встречаются разные способы разделения значений - через запятую или через `-`

# %% [markdown]
# ### Шаг 2.5. Количественные значения
#
# Столбец `budget` уже включает в себя полный объём государственной поддержки. Данные в этом столбце указаны только для тех фильмов, которые получили государственную поддержку. Значит, он не может быть меньше суммы поддержки.

# %%
# проверим подозрительные данные по бюджету
clean_data.query('budget < refundable_support + nonrefundable_support').head()
# Out:
#                   title  pu_number           show_start_date            type  \
# 6322           Баба Яга  114006518 2018-11-08 12:00:00+00:00    Анимационный
# 2683     Тряпичный союз  111010215 2015-06-08 12:00:00+00:00  Художественный
# 2052                14+  111023614 2014-12-19 12:00:00+00:00  Художественный
# 2873  Помню - не помню!  111004916 2016-03-01 12:00:00+00:00  Художественный
# 3738               Мифы  111004317 2017-06-07 12:00:00+00:00  Художественный
#
#                                    film_studio production_country  \
# 6322                  ООО "Арт Пикчерс Студия"             Россия
# 2683             ООО "Кинокомпания "КОКТЕБЕЛЬ"             Россия
# 2052                ООО Киностудия  "Сентябрь"             Россия
# 2873                           ООО "КиноФирма"             Россия
# 3738  ООО "ХАЙПФИЛМ", ООО "Арт Пикчерс Студия"             Россия
#
#           director                                           producer  \
# 6322       В.Саков  ООО "Арт Пикчерс Студия", ООО "КРИЭЙТИВ АНИМЭЙ...
# 2683   М.Местецкий                              Р.Борисевич, А.Кушаев
# 2052      А.Зайцев                                О.Гранина, А.Зайцев
# 2873   В.Ровенский                                    ООО "КиноФирма"
# 3738  А.Молочников  Ф.Бондарчук, Д.Рудовский, И.Стюарт, М.Османн, ...
#
#                       age_restriction  refundable_support  \
# 6322    «6+» - для детей старше 6 лет                 0.0
# 2683      «18+» - запрещено для детей                 0.0
# 2052  «16+» - для детей старше 16 лет                 0.0
# 2873  «12+» - для детей старше 12 лет                 0.0
# 3738  «16+» - для детей старше 16 лет        25,000,000.0
#
#       nonrefundable_support  budget                  financing_source ratings  \
# 6322          138,969,465.0     0.0                         Фонд кино     NaN
# 2683           59,000,000.0     0.0                         Фонд кино     6.3
# 2052           23,000,000.0     0.0  Министерство культуры, Фонд кино     6.6
# 2873            6,000,000.0     0.0             Министерство культуры     4.3
# 3738           20,000,000.0     0.0                         Фонд кино     4.8
#
#              genres   box_office
# 6322        unknown  1,334,699.4
# 2683  комедия,драма  1,957,738.5
# 2052      мелодрама 10,234,016.1
# 2873        комедия 15,362,931.4
# 3738        комедия 50,451,949.0

# %% [markdown]
# Бюджет неизвестен, однако для выборки из 332 фильмов эти данные важны.
# Предположим, что проекты реализовывались только на средства из поддержки.

# %%
clean_data.loc[clean_data['budget'] < clean_data['refundable_support']+clean_data['nonrefundable_support'], 'budget'] = clean_data['refundable_support']+clean_data['nonrefundable_support']

# %%
clean_data.describe()
# Out:
#           pu_number  refundable_support  nonrefundable_support  \
# count       6,823.0             6,823.0                6,823.0
# mean  129,719,571.7           577,312.0            2,383,363.4
# std    32,745,440.4         6,053,077.6           16,900,585.7
# min     1,811,096.0                 0.0                    0.0
# 25%   112,001,769.0                 0.0                    0.0
# 50%   121,013,010.0                 0.0                    0.0
# 75%   122,000,161.0                 0.0                    0.0
# max   231,001,012.0       180,000,000.0          400,000,000.0
#
#                budget      box_office
# count           332.0         3,131.0
# mean    131,422,395.8    75,806,663.5
# std     187,148,242.7   238,195,652.7
# min       6,000,000.0             0.0
# 25%      45,524,799.5        87,802.5
# 50%      71,196,901.5     2,338,788.5
# 75%     150,000,000.0    23,769,707.9
# max   2,305,074,303.0 3,073,568,690.8

# %%
clean_data[clean_data['financing_source'] != 'none'].describe()
# Out:
#           pu_number  refundable_support  nonrefundable_support  \
# count         332.0               332.0                  332.0
# mean  111,593,819.1        11,864,457.8           48,980,988.9
# std     5,703,031.3        24,916,555.3           59,980,117.9
# min   111,000,115.0                 0.0                    0.0
# 25%   111,004,891.5                 0.0           25,000,000.0
# 50%   111,010,367.0                 0.0           30,000,000.0
# 75%   111,017,815.8        15,000,000.0           40,375,000.0
# max   214,010,116.0       180,000,000.0          400,000,000.0
#
#                budget      box_office
# count           332.0           318.0
# mean    131,422,395.8   132,432,420.0
# std     187,148,242.7   334,837,857.0
# min       6,000,000.0         1,550.0
# 25%      45,524,799.5     1,236,675.5
# 50%      71,196,901.5    15,720,067.7
# 75%     150,000,000.0   106,373,008.3
# max   2,305,074,303.0 3,073,568,690.8

# %% [markdown]
# Почему-то нулевые квартили в `refundable_support`

# %%
clean_data[clean_data['financing_source'] != 'none'].boxplot()
plt.ylim(0,600000000)
plt.show()

# %%
# выведем отдельно столбцы, которые не превышают 400 000 000
clean_data[clean_data['financing_source'] != 'none'].boxplot(column=['refundable_support', 'nonrefundable_support'])
plt.show()

# %% [markdown]
# Невозвратных средств поддержки тратится значительно больше

# %%
# выведем отдельно столбцы box_office и budget, ограничим 600 000 000
clean_data[clean_data['financing_source'] != 'none'].boxplot(column=['box_office', 'budget'])
plt.ylim(0,600000000)
plt.show()

# %% [markdown]
# Видно, что сборы меньше, чем бюджеты

# %%
clean_data[clean_data['financing_source'] != 'none'].boxplot()
plt.ylim(0,400000000)
plt.show()

# %%
clean_data['refundable_support'].hist(range=(1,180000000))
plt.show()

# %%
# посмотрим на значения выше 125000000
clean_data.query('refundable_support > 125000000')
# Out:
#                      title  pu_number           show_start_date  \
# 7113  Тайна Печати Дракона  111012819 2019-09-12 12:00:00+00:00
# 3350               Дуэлянт  111015416 2016-09-14 12:00:00+00:00
#
#                 type                                        film_studio  \
# 7113  Художественный  ООО "Кинокомпания "СТВ"; ООО "РФГ Корп"; ООО "...
# 3350  Художественный                            ООО "Нон-Стоп Продакшн"
#
#      production_country     director                   producer  \
# 7113      Россия, Китай  О.Степченко     С.Сельянов, А.Петрухин
# 3350             Россия   А.Мизгирев  А.Роднянский, С.Мелькумов
#
#                       age_restriction  refundable_support  \
# 7113    «6+» - для детей старше 6 лет       180,000,000.0
# 3350  «16+» - для детей старше 16 лет       150,000,000.0
#
#       nonrefundable_support          budget financing_source ratings  \
# 7113           90,000,000.0 2,305,074,303.0        Фонд кино     5.8
# 3350          300,000,000.0   684,200,536.0        Фонд кино     6.6
#
#                    genres    box_office
# 7113  приключения,фэнтези 333,597,059.6
# 3350                драма 364,285,139.6

# %% [markdown]
# Проверили на Кинопоиске, что это не выбросы

# %%
clean_data.plot(kind='scatter', x='refundable_support', y='budget', title='соотношение бюджета и поддержки')
plt.show()

# %%
clean_data['refundable_support'].value_counts()
# Out:
# 0.0              6712
# 20,000,000.0       12
# 10,000,000.0       10
# 25,000,000.0       10
# 15,000,000.0        9
# 5,000,000.0         9
# 50,000,000.0        8
# 40,000,000.0        8
# 30,000,000.0        7
# 60,000,000.0        6
# 100,000,000.0       5
# 110,000,000.0       2
# 55,000,000.0        2
# 19,000,000.0        2
# 75,000,000.0        2
# 7,153,119.0         1
# 35,000,000.0        1
# 9,000,000.0         1
# 150,000,000.0       1
# 36,000,000.0        1
# 29,000,000.0        1
# 17,000,000.0        1
# 180,000,000.0       1
# 115,000,000.0       1
# 41,000,000.0        1
# 26,000,000.0        1
# 7,000,000.0         1
# 7,346,881.0         1
# 3,500,000.0         1
# 8,000,000.0         1
# 38,000,000.0        1
# 44,000,000.0        1
# 28,000,000.0        1
# 80,000,000.0        1
# Name: refundable_support, dtype: int64

# %%
clean_data[(clean_data['financing_source'] != 'none') & (clean_data['refundable_support'] > 0)].boxplot(column='refundable_support')
plt.show()

# %%
clean_data.plot(kind='scatter', x='nonrefundable_support', y='budget', title='Соотношение бюджета и размера поддержки')
plt.show()

# %% [markdown]
# ### Шаг 2.6. Новые столбцы

# %% [markdown]
# - столбец с информацией о годе проката.

# %%
new_data = clean_data.copy()

# Выделим год из даты премьеры фильма.
new_data['show_start_date_year'] = new_data['show_start_date'].dt.year
new_data.head()
# Out:
#                                                 title  pu_number  \
# 1782                        Анжелика, маркиза ангелов  121031913
# 933                                      Летние войны  124002812
# 914   В тумане /По одноименной повести Василя Быкова/  121027712
# 1126                                          Марафон  111006712
# 2218                     Прогулка по солнечному свету  121011614
#
#                show_start_date            type  \
# 1782 2013-12-12 12:00:00+00:00  Художественный
# 933  2012-10-25 12:00:00+00:00    Анимационный
# 914  2012-11-07 12:00:00+00:00  Художественный
# 1126 2012-12-18 12:00:00+00:00  Художественный
# 2218 2014-06-11 12:00:00+00:00  Художественный
#
#                                             film_studio  \
# 1782                  Европа Корп., МонаФилм, ВилмаФилм
# 933   Медхауз, Ниппон Телевижн Нетуорк Корпорейшн, К...
# 914   Ма Йа Де Фикшн, Лемминг Филм, Беларусьфильм, Д...
# 1126                            ООО "Синема Арт Студио"
# 2218                         Вертиго Филмз, АйЭм Глобал
#
#                                   production_country  \
# 1782                                         Франция
# 933                                           Япония
# 914   Германия, Нидерланды, Беларусь, Россия, Латвия
# 1126                                          Россия
# 2218                                  Великобритания
#
#                         director  \
# 1782               Ариэль Зейтун
# 933                Мамору Хосода
# 914               Сергей Лозница
# 1126                  К.Оганесян
# 2218  Макс Джива, Дания Пасквини
#
#                                                producer  \
# 1782        Эммануэль Жаклин, Павел Солк, Филипп Херинг
# 933   Такафуми Ватанабэ, Такуя Ито, Сэйдзи Окуда, Юи...
# 914                                        Хайно Декерт
# 1126                                         К.Оганесян
# 2218       Кэролайн Леви, Эллан Нибло, Джеймс Ричардсон
#
#                       age_restriction  refundable_support  \
# 1782  «16+» - для детей старше 16 лет                 0.0
# 933   «12+» - для детей старше 12 лет                 0.0
# 914   «12+» - для детей старше 12 лет                 0.0
# 1126  «16+» - для детей старше 16 лет                 0.0
# 2218  «12+» - для детей старше 12 лет                 0.0
#
#       nonrefundable_support  budget financing_source ratings  \
# 1782                    0.0     NaN             none     8.0
# 933                     0.0     NaN             none     7.7
# 914                     0.0     NaN             none     6.5
# 1126                    0.0     NaN             none     5.5
# 2218                    0.0     NaN             none     6.1
#
#                            genres  box_office  show_start_date_year
# 1782  драма,мелодрама,приключения         0.0                  2013
# 933   аниме,мультфильм,фантастика         0.0                  2012
# 914         драма,военный,история         0.0                  2012
# 1126            комедия,мелодрама         0.0                  2012
# 2218       мюзикл,драма,мелодрама         0.0                  2014

# %% [markdown]
# - два столбца: с именем и фамилией главного режиссёра и основным жанром фильма. В столбцы войдут первые значения из списка режиссёров и жанров соответственно.

# %%
def first_value(string):
    """
    Возвращает первые значения из списка, который передаётся строкой
    """
    
    try:
        list = string.split(',')
        return list[0]
    except:
        return 'error'

# %%
new_data['main_director'] = new_data['director'].apply(first_value)
new_data['main_genre'] = new_data['genres'].apply(first_value)

#проверим переименование
new_data.head(10)
# Out:
#                                                   title  pu_number  \
# 1782                          Анжелика, маркиза ангелов  121031913
# 933                                        Летние войны  124002812
# 914     В тумане /По одноименной повести Василя Быкова/  121027712
# 1126                                            Марафон  111006712
# 2218                       Прогулка по солнечному свету  121011614
# 2077                 Курбан-роман. (История с жертвой).  111009614
# 237                                            Подранки  111007613
# 1387  Экзамен для двоих /По роману Джин Ханфф Корелитц/  121014613
# 2684                                    ПУСТЬ ТАК БУДЕТ  111009815
# 3993                              Стать Джоном Ленноном  121008610
#
#                show_start_date            type  \
# 1782 2013-12-12 12:00:00+00:00  Художественный
# 933  2012-10-25 12:00:00+00:00    Анимационный
# 914  2012-11-07 12:00:00+00:00  Художественный
# 1126 2012-12-18 12:00:00+00:00  Художественный
# 2218 2014-06-11 12:00:00+00:00  Художественный
# 2077 2014-09-02 12:00:00+00:00  Художественный
# 237  2013-10-18 12:00:00+00:00  Художественный
# 1387 2013-06-11 12:00:00+00:00  Художественный
# 2684 2015-06-01 12:00:00+00:00  Художественный
# 3993 2010-05-05 12:00:00+00:00  Художественный
#
#                                             film_studio  \
# 1782                  Европа Корп., МонаФилм, ВилмаФилм
# 933   Медхауз, Ниппон Телевижн Нетуорк Корпорейшн, К...
# 914   Ма Йа Де Фикшн, Лемминг Филм, Беларусьфильм, Д...
# 1126                            ООО "Синема Арт Студио"
# 2218                         Вертиго Филмз, АйЭм Глобал
# 2077                                   ФОНД "ИННОВАЦИЯ"
# 237                               Киностудия "Мосфильм"
# 1387                                       Депф оф Филд
# 2684                ООО ПРОДЮСЕРСКАЯ КОМПАНИЯ "ДЕРЖАВА"
# 3993  Авер Медиа, Экосси Филмз, Филм 4, Норс Вест Ви...
#
#                                   production_country  \
# 1782                                         Франция
# 933                                           Япония
# 914   Германия, Нидерланды, Беларусь, Россия, Латвия
# 1126                                          Россия
# 2218                                  Великобритания
# 2077                                          Россия
# 237                                             СССР
# 1387                                             США
# 2684                                          Россия
# 3993                          Канада, Великобритания
#
#                         director  \
# 1782               Ариэль Зейтун
# 933                Мамору Хосода
# 914               Сергей Лозница
# 1126                  К.Оганесян
# 2218  Макс Джива, Дания Пасквини
# 2077                     С.Юзеев
# 237                    Н.Губенко
# 1387                    Пол Вайц
# 2684                О.Смольников
# 3993              Сэм Тейлор Вуд
#
#                                                producer  \
# 1782        Эммануэль Жаклин, Павел Солк, Филипп Херинг
# 933   Такафуми Ватанабэ, Такуя Ито, Сэйдзи Окуда, Юи...
# 914                                        Хайно Декерт
# 1126                                         К.Оганесян
# 2218       Кэролайн Леви, Эллан Нибло, Джеймс Ричардсон
# 2077                                         М.Галицкая
# 237                                             unknown
# 1387              Пол Вайц, Керри Кохански, Эндрю Миано
# 2684  К.Лавров, Ю.Потапова, В.Бутер, С.Прудников, С....
# 3993         Роберт Бернштейн, Кевин Лоудер, Дуглас Рэй
#
#                       age_restriction  refundable_support  \
# 1782  «16+» - для детей старше 16 лет                 0.0
# 933   «12+» - для детей старше 12 лет                 0.0
# 914   «12+» - для детей старше 12 лет                 0.0
# 1126  «16+» - для детей старше 16 лет                 0.0
# 2218  «12+» - для детей старше 12 лет                 0.0
# 2077  «12+» - для детей старше 12 лет                 0.0
# 237   «12+» - для детей старше 12 лет                 0.0
# 1387  «12+» - для детей старше 12 лет                 0.0
# 2684  «12+» - для детей старше 12 лет                 0.0
# 3993  «16+» - для детей старше 16 лет                 0.0
#
#       nonrefundable_support  budget financing_source ratings  \
# 1782                    0.0     NaN             none     8.0
# 933                     0.0     NaN             none     7.7
# 914                     0.0     NaN             none     6.5
# 1126                    0.0     NaN             none     5.5
# 2218                    0.0     NaN             none     6.1
# 2077                    0.0     NaN             none     NaN
# 237                     0.0     NaN             none     8.2
# 1387                    0.0     NaN             none     5.8
# 2684                    0.0     NaN             none     NaN
# 3993                    0.0     NaN             none     7.5
#
#                            genres  box_office  show_start_date_year  \
# 1782  драма,мелодрама,приключения         0.0                  2013
# 933   аниме,мультфильм,фантастика         0.0                  2012
# 914         драма,военный,история         0.0                  2012
# 1126            комедия,мелодрама         0.0                  2012
# 2218       мюзикл,драма,мелодрама         0.0                  2014
# 2077                      unknown         0.0                  2014
# 237                         драма         0.0                  2013
# 1387      мелодрама,комедия,драма         0.0                  2013
# 2684                      unknown         0.0                  2015
# 3993    драма,мелодрама,биография         0.0                  2010
#
#        main_director main_genre
# 1782   Ариэль Зейтун      драма
# 933    Мамору Хосода      аниме
# 914   Сергей Лозница      драма
# 1126      К.Оганесян    комедия
# 2218      Макс Джива     мюзикл
# 2077         С.Юзеев    unknown
# 237        Н.Губенко      драма
# 1387        Пол Вайц  мелодрама
# 2684    О.Смольников    unknown
# 3993  Сэм Тейлор Вуд      драма

# %% [markdown]
# - какую долю от общего бюджета фильма составляет государственная поддержка.

# %%
new_data['support'] = (new_data['nonrefundable_support']+new_data['refundable_support'])/new_data['budget']
new_data[new_data['support'] > 0].head()
# Out:
#                       title  pu_number           show_start_date  \
# 3148              Я-Учитель  111019715 2015-12-02 12:00:00+00:00
# 2526      Вдвоем на льдине.  111011015 2015-06-25 12:00:00+00:00
# 2802  Битва с экстрасенсами  111011315 2015-07-20 12:00:00+00:00
# 3503                День До  111010916 2016-07-06 12:00:00+00:00
# 2149           РЕВЕРБЕРАЦИЯ  111003515 2015-03-30 12:00:00+00:00
#
#                 type                                        film_studio  \
# 3148  Художественный  НП Киностудия детских и юношеских фильмов "Иль...
# 2526  Художественный                ООО "Первое творческое объединение"
# 2802  Художественный                     ООО "КИНОДАНЦ", ООО "КИНОБАЙТ"
# 3503  Художественный          ООО "Кинобюро" по заказу ООО "Среда и Ко"
# 2149  Художественный                                      ООО "Артлайт"
#
#      production_country                                     director  \
# 3148             Россия                                  С.Мокрицкий
# 2526             Россия                     Н.Джорджадзе, В.Игнатьев
# 2802             Россия                                   И.Кордзаия
# 3503             Россия  А.Котт, В.Котт, А.Карпиловский, Б.Хлебников
# 2149             Россия                                  К.Сухарьков
#
#                   producer                  age_restriction  \
# 3148            А.Ковтунец  «12+» - для детей старше 12 лет
# 2526  П.Поляков, И.Букреев  «12+» - для детей старше 12 лет
# 2802           Е.Мелентьев  «12+» - для детей старше 12 лет
# 3503      А.Цекало, А.Котт      «18+» - запрещено для детей
# 2149             А.Новиков      «18+» - запрещено для детей
#
#       refundable_support  nonrefundable_support       budget  \
# 3148                 0.0           35,000,000.0 91,000,000.0
# 2526                 0.0           26,500,000.0 37,943,652.0
# 2802                 0.0           25,900,000.0 59,560,746.0
# 3503        25,000,000.0           25,000,000.0 90,822,766.0
# 2149                 0.0           25,000,000.0 37,371,262.0
#
#                       financing_source ratings               genres  \
# 3148             Министерство культуры     7.4    мелодрама,комедия
# 2526             Министерство культуры     6.6            мелодрама
# 2802  Министерство культуры, Фонд кино     5.4  фэнтези,приключения
# 3503                         Фонд кино     4.8     драма,фантастика
# 2149             Министерство культуры     NaN              unknown
#
#       box_office  show_start_date_year main_director main_genre  support
# 3148     1,550.0                  2015   С.Мокрицкий  мелодрама      0.4
# 2526     4,450.0                  2015  Н.Джорджадзе  мелодрама      0.7
# 2802     6,000.0                  2015    И.Кордзаия    фэнтези      0.4
# 3503     9,000.0                  2016        А.Котт      драма      0.6
# 2149    19,820.0                  2015   К.Сухарьков    unknown      0.7

# %% [markdown]
# ### Промежуточные итоги

# %% [markdown]
# 1. Проверили типы данных в датафрейме и преобразовали их там, где это необходимо:
# - `show_start_date` — дата премьеры фильма - преобразовали в `datetime`
# - `ratings` *—* рейтинг фильма на КиноПоиске - преобразовали в `float`. В рейтинге обнаружились значения с `%`. Мы проверили на Кинопоиске несколько фильмов - рейтинг ошибочен не только форматированием, но и значением.
#
# Категорийные столбцы оставили строковыми
#
# 2. В 11 столбцах были обнаружены пропуски. Мы обработали их и оставили пропуски в 3х:
# - `film_studio` - пропуски заполнили значением `unknown`
# - `production_country` - пропуски заполнили значением `Россия`
# - `director` - пропуски заполнили значением `unknown`
# - `producer` - пропуски заполнили значением `unknown`
# - `refundable_support` - пропуски заполнили `0`
# - `nonrefundable_support` - пропуски заполнили `0`
# - `budget` - поддержки не было, но заполнить `0` кажется неправильно, так как бюджет всё же не нулевой
# - `financing_source` - пропуски заполнили `none`
# - `ratings` - заполнить `0` кажется неправильно, так как рейтинг всё же не нулевой
# - `genres` - пропуски заполнили `unknown`
# - `box_office` - заполнить `0` кажется неправильно, так как рейтинг всё же не нулевой
# 3. Обработали дубликаты. В датафрейме много фильмов с одинаковыми данными, но разными прокатными удостоверениями. Также прокатные удостовериения, для которых была указана сумма в прокате `box_office` могли уже находиться в датафрейме под другими прокатными удостоверениями.
# 4. Общая проблема почти во всех категориальных столбцах:
# - перечисления нексольких объектов в разном порядке (порядок не изменяли, так как он может означать важность)
# - также встречаются разные способы разделения значений - через запятую или через `-` - исправили это на универсальные разделители
# 5. Столбец `budget` включал нулевые значения. Данные в этом столбце указаны только для тех фильмов, которые получили государственную поддержку. Значит, он не может быть меньше суммы поддержки. Приняли бюджет в этих строках равным сумме поддержки
# 6. Создали несколько новых столюцов для упрощения анализа

# %% [markdown]
# ## Шаг 3. Исследовательский анализ данных

# %% [markdown]
# - Посмотрим, сколько фильмов выходило в прокат каждый год. Данные о прокате в кинотеатрах известны не для всех фильмов.
# - Посчитаем, какую долю составляют фильмы с указанной информацией о прокате в кинотеатрах.

# %%
# проверим диапазон значений
new_data['show_start_date_year'].unique()
# Out:
# array([2013, 2012, 2014, 2015, 2010, 2016, 2011, 2019, 2017, 2018])

# %%
# сводная таблица по фильмам
box_office_info = new_data.pivot_table(index='show_start_date_year', values=['title', 'box_office'], aggfunc='count')
box_office_info['pct'] = box_office_info['box_office']/box_office_info['title']
box_office_info
# Out:
#                       box_office  title  pct
# show_start_date_year
# 2010                         101    766  0.1
# 2011                         108    484  0.2
# 2012                         126    523  0.2
# 2013                         182    590  0.3
# 2014                         275    737  0.4
# 2015                         458    668  0.7
# 2016                         519    739  0.7
# 2017                         357    500  0.7
# 2018                         475    887  0.5
# 2019                         530    929  0.6

# %% [markdown]
# **Вывод:**
# В период с 2010 по 2019 год наименьшее количество фильмов в данных мы видим за 2011 год. В 2010 их было значительно больше, возврат к этому высокому уровню пришёлся на 2014-2016 годы. Затем в 2017м снова 500 значений и подъём в 2018м и 19м годах.
# Данных по сборам в кинотеатрах с 2010 по 2014 годы достаточно мало относительно известных нам фильмов. с 2015го года доля с у казанной информацией о прокате - 0.5-0.7

# %%
(
    new_data
    .pivot_table(index='show_start_date_year', values=['title', 'box_office'], aggfunc='count')
    .plot(kind='bar', 
                     title='Количество фильмов по годам',
                     xlabel='Год выхода в прокат'
                    )
)
plt.legend(["Кол-во фильмов с известной выручкой", "Количество фильмов"]);
plt.show()

# %%
box_office_info['pct'].plot(kind='bar', 
                     title='Доля фильмов с указанной информацией о прокате в кинотеатрах',
                     xlabel='Год выхода в прокат',
                           ylabel='доли')
plt.show()

# %% [markdown]
# Данных по сборам в кинотеатрах с 2010 по 2014 годы достаточно мало относительно известных нам фильмов (10-40%). с 2015го года доля с у казанной информацией о прокате - 50-70%

# %%
# доля фильмов с указанной информацией о прокате в кинотеатрах за всё время
new_data['box_office'].count()/new_data['title'].count()
# Out:
# 0.4588890517367727

# %% [markdown]
# - Изучим, как менялась динамика проката по годам. В каком году сумма сборов была минимальной? А максимальной?

# %%
# сводная таблица по сумме в прокате
new_data.pivot_table(index='show_start_date_year', values='box_office', aggfunc='sum').plot(
    title='динамика проката по годам', xlabel='годы', ylabel='Сумма. руб.')
plt.legend(["Сумма сборов в прокате"]);
plt.show()

# %%
new_data.pivot_table(index='show_start_date_year', values='box_office', aggfunc='sum')
# Out:
#                            box_office
# show_start_date_year
# 2010                      2,148,764.0
# 2011                     13,997,065.0
# 2012                      6,842,683.0
# 2013                     29,775,666.2
# 2014                  7,444,140,111.2
# 2015                 38,263,253,872.1
# 2016                 44,932,686,064.3
# 2017                 48,563,707,217.5
# 2018                 49,668,403,134.3
# 2019                 48,425,708,779.6

# %% [markdown]
# **Вывод:**
# По известным данным в 2010 году сумма в прокате была минимальной. Максимальной - в 2018м году.

# %% [markdown]
# - С помощью сводной таблицы посчитаем среднюю и медианную сумму сборов для каждого года.

# %%
new_data.pivot_table(index='show_start_date_year', values='box_office', aggfunc=['median', 'mean'])
# Out:
#                           median          mean
#                       box_office    box_office
# show_start_date_year
# 2010                     1,590.0      21,274.9
# 2011                     2,952.5     129,602.5
# 2012                     5,260.0      54,307.0
# 2013                     3,475.0     163,602.6
# 2014                    18,160.0  27,069,600.4
# 2015                 4,777,096.2  83,544,222.4
# 2016                 3,778,317.8  86,575,503.0
# 2017                 9,968,340.0 136,032,793.3
# 2018                 8,891,102.2 104,565,059.2
# 2019                 4,627,798.3  91,369,261.8

# %% [markdown]
# **Вывод:**
# с 2015 года средняя сумма сборов резко возросла, но тогда и данных о сборах появилось значительно больше

# %%
# ещё раз посмотрим на квартили
new_data.describe()
# Out:
#           pu_number  refundable_support  nonrefundable_support  \
# count       6,823.0             6,823.0                6,823.0
# mean  129,719,571.7           577,312.0            2,383,363.4
# std    32,745,440.4         6,053,077.6           16,900,585.7
# min     1,811,096.0                 0.0                    0.0
# 25%   112,001,769.0                 0.0                    0.0
# 50%   121,013,010.0                 0.0                    0.0
# 75%   122,000,161.0                 0.0                    0.0
# max   231,001,012.0       180,000,000.0          400,000,000.0
#
#                budget      box_office  show_start_date_year  support
# count           332.0         3,131.0               6,823.0    332.0
# mean    131,422,395.8    75,806,663.5               2,014.8      0.5
# std     187,148,242.7   238,195,652.7                   3.0      0.2
# min       6,000,000.0             0.0               2,010.0      0.0
# 25%      45,524,799.5        87,802.5               2,012.0      0.4
# 50%      71,196,901.5     2,338,788.5               2,015.0      0.6
# 75%     150,000,000.0    23,769,707.9               2,018.0      0.7
# max   2,305,074,303.0 3,073,568,690.8               2,019.0      1.0

# %%
# ограничим выбросы до 24 000 000
new_data[new_data['box_office'] < 24000000].pivot_table(index='show_start_date_year', 
                                                         values='box_office', 
                                                         aggfunc=['median', 'mean'])
# Out:
#                           median        mean
#                       box_office  box_office
# show_start_date_year
# 2010                     1,590.0    21,274.9
# 2011                     2,952.5   129,602.5
# 2012                     5,260.0    54,307.0
# 2013                     3,475.0   163,602.6
# 2014                    13,860.0   929,830.4
# 2015                 1,449,868.4 4,299,178.1
# 2016                 1,291,533.0 3,697,970.7
# 2017                 3,094,683.0 5,753,509.5
# 2018                 3,642,053.0 6,002,265.0
# 2019                 2,188,649.9 4,132,651.7

# %% [markdown]
# Большая разница среднего и медианы обусловлена выбросами. Большая часть фильмов зарабатывает до 24 млн. в прокате, однако есть выбросы до 3х млрд. Если ограничить выборку сверху, среднее и медиана будут сближаться

# %% [markdown]
# - Определим, влияет ли возрастное ограничение аудитории («6+», «12+», «16+», «18+» и т. д.) на сборы фильма в прокате в период с 2015 по 2019 год.
# - Фильмы с каким возрастным ограничением собрали больше всего денег в прокате? Меняется ли картина в зависимости от года?

# %%
new_data[new_data['show_start_date_year'] >= 2015].pivot_table(index='show_start_date_year', columns='age_restriction', values='box_office', aggfunc='sum')
# Out:
# age_restriction       «0+» - для любой зрительской аудитории  \
# show_start_date_year
# 2015                                           273,367,887.8
# 2016                                           150,228,848.7
# 2017                                           229,598,930.0
# 2018                                            32,449,002.1
# 2019                                            17,746,066.8
#
# age_restriction       «12+» - для детей старше 12 лет  \
# show_start_date_year
# 2015                                 13,616,082,008.9
# 2016                                 12,179,462,355.0
# 2017                                  7,851,427,660.7
# 2018                                 14,267,291,660.7
# 2019                                 12,680,198,773.7
#
# age_restriction       «16+» - для детей старше 16 лет  \
# show_start_date_year
# 2015                                 10,537,061,602.6
# 2016                                 16,628,961,166.6
# 2017                                 18,745,042,900.1
# 2018                                 16,503,602,347.0
# 2019                                 12,753,418,984.6
#
# age_restriction       «18+» - запрещено для детей  \
# show_start_date_year
# 2015                              5,137,465,401.4
# 2016                              6,793,929,818.9
# 2017                              9,651,495,581.0
# 2018                              8,760,085,501.1
# 2019                             10,121,796,303.6
#
# age_restriction       «6+» - для детей старше 6 лет
# show_start_date_year
# 2015                                8,699,276,971.4
# 2016                                9,180,103,875.1
# 2017                               12,086,142,145.8
# 2018                               10,104,974,623.4
# 2019                               12,852,548,650.9

# %%
new_data[new_data['show_start_date_year'] >= 2015].pivot_table(index='show_start_date_year', columns='age_restriction', values='box_office', aggfunc='count')
# Out:
# age_restriction       «0+» - для любой зрительской аудитории  \
# show_start_date_year
# 2015                                                      37
# 2016                                                      41
# 2017                                                       3
# 2018                                                       5
# 2019                                                       3
#
# age_restriction       «12+» - для детей старше 12 лет  \
# show_start_date_year
# 2015                                               73
# 2016                                               81
# 2017                                               41
# 2018                                               67
# 2019                                               85
#
# age_restriction       «16+» - для детей старше 16 лет  \
# show_start_date_year
# 2015                                              165
# 2016                                              178
# 2017                                              121
# 2018                                              156
# 2019                                              178
#
# age_restriction       «18+» - запрещено для детей  \
# show_start_date_year
# 2015                                          131
# 2016                                          151
# 2017                                          147
# 2018                                          179
# 2019                                          183
#
# age_restriction       «6+» - для детей старше 6 лет
# show_start_date_year
# 2015                                             52
# 2016                                             68
# 2017                                             45
# 2018                                             68
# 2019                                             81

# %%
new_data[(new_data['show_start_date_year'] == 2019) & (new_data['age_restriction'] == '«0+» - для любой зрительской аудитории')].sort_values(by='box_office').head()
# Out:
#                                                   title  pu_number  \
# 6935  Антон Чехов и Исаак Левитан: двойной портрет в...  112004019
# 7386              Робокар Поли: Приключение в Брумтауне  124009719
# 6840                                          Букашки 2  124002019
# 6400         Белка и Стрелка. Тайны космоса (1-5 серии)  114007518
# 6562                          МУЛЬТ в кино. Выпуск № 88  114009918
#
#                show_start_date            type  \
# 6935 2019-06-01 12:00:00+00:00  Документальный
# 7386 2019-11-21 12:00:00+00:00    Анимационный
# 6840 2019-04-25 12:00:00+00:00    Анимационный
# 6400 2019-02-15 12:00:00+00:00    Анимационный
# 6562 2019-01-05 12:00:00+00:00    Анимационный
#
#                                             film_studio production_country  \
# 6935                             ООО "КИНОСТУДИЯ "РОЗА"             Россия
# 7386                                           Рой Вижл        Южная Корея
# 6840  Фьютрукен, ИфилмИнтертейнмент, Франс 3 Синема,...       Франция, КНР
# 6400                                     ООО "КиноАтис"             Россия
# 6562                                 ООО "Мульт в кино"             Россия
#
#                     director                                 producer  \
# 6935             Г.Евтушенко                              Г.Евтушенко
# 7386            Джун Янг Йом  Донг Ву Лии, Сеонг Су Ким, Най Янг Квак
# 6840   Элен Жиро, Томас Сабо                            Филипп Деларю
# 6400  А.Рубецкой, Е.Шабанова                      В.Сотсков, С.Зернов
# 6562              О Семёнова                                П.Смирнов
#
#                              age_restriction  refundable_support  \
# 6935  «0+» - для любой зрительской аудитории                 0.0
# 7386  «0+» - для любой зрительской аудитории                 0.0
# 6840  «0+» - для любой зрительской аудитории                 0.0
# 6400  «0+» - для любой зрительской аудитории                 0.0
# 6562  «0+» - для любой зрительской аудитории                 0.0
#
#       nonrefundable_support  budget financing_source ratings  \
# 6935                    0.0     NaN             none     NaN
# 7386                    0.0     NaN             none     NaN
# 6840                    0.0     NaN             none     7.2
# 6400                    0.0     NaN             none     NaN
# 6562                    0.0     NaN             none     NaN
#
#                               genres   box_office  show_start_date_year  \
# 6935                         unknown     81,000.0                  2019
# 7386                         unknown  3,885,434.5                  2019
# 6840  мультфильм,комедия,приключения 13,779,632.3                  2019
# 6400                         unknown          NaN                  2019
# 6562                         unknown          NaN                  2019
#
#      main_director  main_genre  support
# 6935   Г.Евтушенко     unknown      NaN
# 7386  Джун Янг Йом     unknown      NaN
# 6840     Элен Жиро  мультфильм      NaN
# 6400    А.Рубецкой     unknown      NaN
# 6562    О Семёнова     unknown      NaN

# %% [markdown]
# **Вывод:**
# - 2015 - 12+
# - 2016 - 16+
# - 2017 - 16+
# - 2018 - 16+
# - 2019 - 0+
#
# Категории `12+` и `16+` очень близки по сборам (кроме 2017 года), и собирают больше всего денег в указанный период. То, что категория 16+ вышла вперёд, вероятно, связано с ужесточением критериев категоризации (больше фильмов стало попадать в эту категорию)
#
# В 2019 году лидером стала категория 0+ - в ней есть значительный вклад мультфильма "Букашки 2"

# %%
new_data[new_data['show_start_date_year'] >= 2015].pivot_table(index='show_start_date_year', 
                                                               columns='age_restriction', 
                                                               values='box_office', aggfunc=['median', 'mean'])
# Out:
#                                                      median  \
# age_restriction      «0+» - для любой зрительской аудитории
# show_start_date_year
# 2015                                            2,591,302.5
# 2016                                            2,571,294.1
# 2017                                           22,178,956.0
# 2018                                            3,616,937.3
# 2019                                            3,885,434.5
#
#                                                       \
# age_restriction      «12+» - для детей старше 12 лет
# show_start_date_year
# 2015                                    15,351,562.5
# 2016                                     4,535,915.5
# 2017                                     9,010,548.0
# 2018                                     8,931,965.7
# 2019                                     3,405,545.8
#
#                                                       \
# age_restriction      «16+» - для детей старше 16 лет
# show_start_date_year
# 2015                                     4,321,194.6
# 2016                                     5,281,042.1
# 2017                                     9,702,077.0
# 2018                                     9,010,638.6
# 2019                                     3,210,717.8
#
#                                                   \
# age_restriction      «18+» - запрещено для детей
# show_start_date_year
# 2015                                 4,578,468.0
# 2016                                 6,107,001.7
# 2017                                 8,212,677.0
# 2018                                 7,179,466.0
# 2019                                 5,603,216.5
#
#                                                     \
# age_restriction      «6+» - для детей старше 6 лет
# show_start_date_year
# 2015                                  23,125,984.7
# 2016                                   2,504,627.6
# 2017                                  51,992,103.0
# 2018                                  14,688,850.3
# 2019                                  12,875,350.3
#
#                                                        mean  \
# age_restriction      «0+» - для любой зрительской аудитории
# show_start_date_year
# 2015                                            7,388,321.3
# 2016                                            3,664,118.3
# 2017                                           76,532,976.7
# 2018                                            6,489,800.4
# 2019                                            5,915,355.6
#
#                                                       \
# age_restriction      «12+» - для детей старше 12 лет
# show_start_date_year
# 2015                                   186,521,671.4
# 2016                                   150,363,732.8
# 2017                                   191,498,235.6
# 2018                                   212,944,651.7
# 2019                                   149,178,809.1
#
#                                                       \
# age_restriction      «16+» - для детей старше 16 лет
# show_start_date_year
# 2015                                    63,860,979.4
# 2016                                    93,421,130.1
# 2017                                   154,917,709.9
# 2018                                   105,792,322.7
# 2019                                    71,648,421.3
#
#
# age_restriction      «18+» - запрещено для детей «6+» - для детей старше 6 лет
# show_start_date_year
# 2015                                39,217,293.1                 167,293,787.9
# 2016                                44,992,912.7                 135,001,527.6
# 2017                                65,656,432.5                 268,580,936.6
# 2018                                48,939,025.1                 148,602,568.0
# 2019                                55,310,362.3                 158,673,440.1

# %% [markdown]
# Медиана:
# - 2015 - **6+**
# - 2016 - **18+**
# - 2017 - 16+
# - 2018 - **6+**
# - 2019 - **6+**
#
# В отличие от суммы, медианное значение выше в категории 6+ - для детей старше 6 лет.
#
# Среднее:
# - 2015 - **6+**
# - 2016 - **12+**
# - 2017 - **6+**
# - 2018 - **12+**
# - 2019 - **6+**
#
# В отличие от суммы, среднее значение каждый год выше в категории 6+ и 12+ поочерёдно.
#
# **В сумме категория 16+ преобладает за счёт количества фильмов**

# %%
new_data[new_data['show_start_date_year'] >= 2015].boxplot(by='age_restriction', 
                                                           figsize=(15,5), 
                                                           column='box_office')
plt.title('Сборы по возрастной группе')
plt.ylim(0,500000000)
plt.show()

# %% [markdown]
# ### Шаг 4. Исследуйте фильмы, которые получили государственную поддержку
#
# - сколько выделяют средств на поддержку кино.
# - хорошо ли окупаются такие фильмы
# - какой у них рейтинг.

# %%
# выделим фильмы с поддержкой в отдельный датафрейм
supported = new_data[(clean_data['financing_source'] != 'none')]

# %%
supported.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 332 entries, 3148 to 7477
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  332 non-null    object
#  1   pu_number              332 non-null    int64
#  2   show_start_date        332 non-null    datetime64[ns, UTC]
#  3   type                   332 non-null    object
#  4   film_studio            332 non-null    object
#  5   production_country     332 non-null    object
#  6   director               332 non-null    object
#  7   producer               332 non-null    object
#  8   age_restriction        332 non-null    object
#  9   refundable_support     332 non-null    float64
#  10  nonrefundable_support  332 non-null    float64
#  11  budget                 332 non-null    float64
#  12  financing_source       332 non-null    object
#  13  ratings                314 non-null    object
#  14  genres                 332 non-null    object
#  15  box_office             318 non-null    float64
#  16  show_start_date_year   332 non-null    int64
#  17  main_director          332 non-null    object
#  18  main_genre             332 non-null    object
#  19  support                332 non-null    float64
# dtypes: datetime64[ns, UTC](1), float64(5), int64(2), object(12)
# memory usage: 54.5+ KB

# %%
# описание количественных параметров
supported.describe()
# Out:
#           pu_number  refundable_support  nonrefundable_support  \
# count         332.0               332.0                  332.0
# mean  111,593,819.1        11,864,457.8           48,980,988.9
# std     5,703,031.3        24,916,555.3           59,980,117.9
# min   111,000,115.0                 0.0                    0.0
# 25%   111,004,891.5                 0.0           25,000,000.0
# 50%   111,010,367.0                 0.0           30,000,000.0
# 75%   111,017,815.8        15,000,000.0           40,375,000.0
# max   214,010,116.0       180,000,000.0          400,000,000.0
#
#                budget      box_office  show_start_date_year  support
# count           332.0           318.0                 332.0    332.0
# mean    131,422,395.8   132,432,420.0               2,016.7      0.5
# std     187,148,242.7   334,837,857.0                   1.6      0.2
# min       6,000,000.0         1,550.0               2,013.0      0.0
# 25%      45,524,799.5     1,236,675.5               2,015.0      0.4
# 50%      71,196,901.5    15,720,067.7               2,017.0      0.6
# 75%     150,000,000.0   106,373,008.3               2,018.0      0.7
# max   2,305,074,303.0 3,073,568,690.8               2,019.0      1.0

# %%
supported.boxplot(figsize=(15,5), column=['refundable_support', 'nonrefundable_support', 'budget', 'box_office'])
plt.title('Количественные параметры фильмов с гос. поддержкой')
plt.ylim(0,600000000)
plt.show()

# %% [markdown]
# - `refundable_support` *—* объём возвратных средств государственной поддержки меньше, чем объём невозвратных средств (в среднем почти в 5 раз, и разброс значений небольшой)
# - `nonrefundable_support` *—* объём невозвратных средств государственной поддержки чаще всего предоставляется от 0 до 40 000 000.
#
# Финансирование как правило составляет половину бюджета фильма.
# **За исключением нескольких фильмов сборы меньше чем бюджет.**
#
# - `ratings` *—* рейтинг фильма на КиноПоиске только у 314 из 332 - удалим пропуски и посмотрим отдельно на графике

# %%
supported.plot(kind='scatter', 
               c='nonrefundable_support', 
               x='budget', 
               xlabel='Бюджет фильма',
               y='box_office', 
               ylabel='сборы в кинотеатрах',
               colormap='viridis', 
               title='соотношение бюджета и выручки',
              figsize=(8,5))
plt.xlabel("Бюджет фильма")
plt.show()

# %%
# выделим фильмы, у которых сборы в прокате больше, чем бюджет
successful = supported.query('box_office > budget')
successful.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79 entries, 2873 to 7455
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   title                  79 non-null     object
#  1   pu_number              79 non-null     int64
#  2   show_start_date        79 non-null     datetime64[ns, UTC]
#  3   type                   79 non-null     object
#  4   film_studio            79 non-null     object
#  5   production_country     79 non-null     object
#  6   director               79 non-null     object
#  7   producer               79 non-null     object
#  8   age_restriction        79 non-null     object
#  9   refundable_support     79 non-null     float64
#  10  nonrefundable_support  79 non-null     float64
#  11  budget                 79 non-null     float64
#  12  financing_source       79 non-null     object
#  13  ratings                78 non-null     object
#  14  genres                 79 non-null     object
#  15  box_office             79 non-null     float64
#  16  show_start_date_year   79 non-null     int64
#  17  main_director          79 non-null     object
#  18  main_genre             79 non-null     object
#  19  support                79 non-null     float64
# dtypes: datetime64[ns, UTC](1), float64(5), int64(2), object(12)
# memory usage: 13.0+ KB

# %%
# параметры для анализа
supported.head()
# Out:
#                       title  pu_number           show_start_date  \
# 3148              Я-Учитель  111019715 2015-12-02 12:00:00+00:00
# 2526      Вдвоем на льдине.  111011015 2015-06-25 12:00:00+00:00
# 2802  Битва с экстрасенсами  111011315 2015-07-20 12:00:00+00:00
# 3503                День До  111010916 2016-07-06 12:00:00+00:00
# 2149           РЕВЕРБЕРАЦИЯ  111003515 2015-03-30 12:00:00+00:00
#
#                 type                                        film_studio  \
# 3148  Художественный  НП Киностудия детских и юношеских фильмов "Иль...
# 2526  Художественный                ООО "Первое творческое объединение"
# 2802  Художественный                     ООО "КИНОДАНЦ", ООО "КИНОБАЙТ"
# 3503  Художественный          ООО "Кинобюро" по заказу ООО "Среда и Ко"
# 2149  Художественный                                      ООО "Артлайт"
#
#      production_country                                     director  \
# 3148             Россия                                  С.Мокрицкий
# 2526             Россия                     Н.Джорджадзе, В.Игнатьев
# 2802             Россия                                   И.Кордзаия
# 3503             Россия  А.Котт, В.Котт, А.Карпиловский, Б.Хлебников
# 2149             Россия                                  К.Сухарьков
#
#                   producer                  age_restriction  \
# 3148            А.Ковтунец  «12+» - для детей старше 12 лет
# 2526  П.Поляков, И.Букреев  «12+» - для детей старше 12 лет
# 2802           Е.Мелентьев  «12+» - для детей старше 12 лет
# 3503      А.Цекало, А.Котт      «18+» - запрещено для детей
# 2149             А.Новиков      «18+» - запрещено для детей
#
#       refundable_support  nonrefundable_support       budget  \
# 3148                 0.0           35,000,000.0 91,000,000.0
# 2526                 0.0           26,500,000.0 37,943,652.0
# 2802                 0.0           25,900,000.0 59,560,746.0
# 3503        25,000,000.0           25,000,000.0 90,822,766.0
# 2149                 0.0           25,000,000.0 37,371,262.0
#
#                       financing_source ratings               genres  \
# 3148             Министерство культуры     7.4    мелодрама,комедия
# 2526             Министерство культуры     6.6            мелодрама
# 2802  Министерство культуры, Фонд кино     5.4  фэнтези,приключения
# 3503                         Фонд кино     4.8     драма,фантастика
# 2149             Министерство культуры     NaN              unknown
#
#       box_office  show_start_date_year main_director main_genre  support
# 3148     1,550.0                  2015   С.Мокрицкий  мелодрама      0.4
# 2526     4,450.0                  2015  Н.Джорджадзе  мелодрама      0.7
# 2802     6,000.0                  2015    И.Кордзаия    фэнтези      0.4
# 3503     9,000.0                  2016        А.Котт      драма      0.6
# 2149    19,820.0                  2015   К.Сухарьков    unknown      0.7

# %%
supported.plot(kind='scatter', 
               x='show_start_date_year', 
               xlabel='годы',
               y='budget', 
               ylabel='бюджет',
               title='бюджет по годам')
plt.show()

# %%
supported.pivot_table(index='show_start_date_year', values='budget', aggfunc='sum').plot(kind='line', 
               xlabel='годы',
               ylabel='бюджет',
               title='бюджет по годам')
plt.show()

# %%
supported.pivot_table(index='show_start_date_year', values=['budget', 'box_office'], aggfunc=['sum', 'count'])
# Out:
#                                   sum                       count
#                            box_office           budget box_office budget
# show_start_date_year
# 2013                     20,322,385.1    255,435,390.0          2      2
# 2014                  1,017,422,166.6  1,302,484,783.0         16     16
# 2015                  5,785,285,418.1  7,738,669,207.0         85     86
# 2016                  6,081,707,839.1  7,554,942,748.0         60     61
# 2017                 10,865,075,301.0  7,057,172,568.0         39     41
# 2018                  9,934,069,010.2  7,000,664,099.0         56     56
# 2019                  8,409,627,454.6 12,722,866,609.0         60     70

# %% [markdown]
# Начиная с 2015 года бюджет фильмов с гос. поддержкой был в сумме 7 - 7.5 млрд. рублей. в 2019м году - рекордные 12.7 млрд. При этом в 2015, 2016 и 2019 годах эти бюджеты не окупились.

# %%
supported.pivot_table(index='type', values='budget', aggfunc=['sum', 'count'])
# Out:
#                             sum  count
#                          budget budget
# type
# Анимационный    5,909,423,882.0     31
# Документальный     33,000,000.0      1
# Художественный 37,689,811,522.0    300

# %% [markdown]
# В основном гос. поддержкой пользуются Художественные фильмы.

# %%
supported.pivot_table(index='main_genre', values='budget', aggfunc=['sum', 'count'])
# Out:
#                          sum  count
#                       budget budget
# main_genre
# unknown      1,081,930,919.0     16
# биография      528,933,637.0      3
# боевик         683,436,808.0      6
# военный      1,285,906,825.0      9
# детектив     1,198,222,297.0      5
# детский        183,898,004.0      4
# драма       11,126,886,688.0     93
# история      2,145,062,206.0      4
# комедия      6,150,586,880.0     74
# криминал       426,594,781.0      3
# мелодрама      941,005,334.0     15
# мультфильм   5,815,499,467.0     31
# мюзикл         564,197,472.0      4
# приключения  3,374,742,189.0      7
# реальное ТВ     80,000,000.0      1
# семейный       636,799,787.0      7
# спорт          710,468,965.0      3
# триллер      1,350,960,940.0     15
# ужасы          563,877,625.0     10
# фантастика   2,443,100,815.0     11
# фэнтези      2,340,123,765.0     11

# %% [markdown]
# Драма и комедия - наиболее часто пользуются гос. поддержкой

# %%
successful.pivot_table(index='main_genre', values='budget', aggfunc=['sum', 'count'])
# Out:
#                         sum  count
#                      budget budget
# main_genre
# unknown       148,585,222.0      1
# биография     131,000,000.0      1
# боевик        230,000,000.0      2
# военный       533,884,000.0      3
# драма       3,606,499,446.0     14
# история       500,012,729.0      1
# комедия     2,938,970,219.0     31
# мультфильм  2,061,265,049.0     12
# приключения   528,441,977.0      1
# семейный      397,922,287.0      3
# спорт         680,468,965.0      2
# триллер       199,551,503.0      2
# ужасы         233,800,700.0      3
# фантастика    450,067,392.0      2
# фэнтези        42,000,000.0      1

# %%
supported.pivot_table(index='age_restriction', values='budget', aggfunc=['sum', 'count'])
# Out:
#                                                     sum  count
#                                                  budget budget
# age_restriction
# «0+» - для любой зрительской аудитории    902,984,585.0      8
# «12+» - для детей старше 12 лет        15,587,946,009.0    106
# «16+» - для детей старше 16 лет        11,841,591,936.0    125
# «18+» - запрещено для детей             2,309,837,155.0     28
# «6+» - для детей старше 6 лет          12,989,875,719.0     65

# %%
successful.pivot_table(index='age_restriction', values='budget', aggfunc=['sum', 'count'])
# Out:
#                                                    sum  count
#                                                 budget budget
# age_restriction
# «0+» - для любой зрительской аудитории   252,489,571.0      1
# «12+» - для детей старше 12 лет        5,849,617,604.0     30
# «16+» - для детей старше 16 лет        1,905,974,133.0     25
# «18+» - запрещено для детей              129,853,412.0      2
# «6+» - для детей старше 6 лет          4,544,534,769.0     21

# %%
# данные об оценках для фильмов с господдержкой и для тех, у которых сумма сборов превысила бюджет
supported_ratings = supported.pivot_table(index='ratings', values='budget', aggfunc=['sum', 'count'])
successful_ratings = successful.pivot_table(index='ratings', values='budget', aggfunc=['sum', 'count'])

# %%
supported_ratings.plot(kind='bar', figsize=(12,6), title='рейтинг фильмов с поддержкой')
plt.show()

# %% [markdown]
# наиболее частые оценки - 5.7 - 6.9

# %%
successful_ratings.plot(kind='bar', figsize=(12,6), title='рейтинг фильмов с поддержкой')
plt.show()

# %% [markdown]
# Фильмы, достигшие кассового успеха, соответственно и оценки имеют выше - чаще 6.4 - 7.6

# %%
supported.hist(figsize=(12,9))
plt.show()

# %%
successful.hist(figsize=(12,9))
plt.show()

# %% [markdown]
# ### Шаг 5. Общий вывод

# %% [markdown]
# #### Краткий обзор проведённой работы.
# В приведённом исследовании стояла задача изучить рынок российского кинопроката и выявить текущие тренды. Уделить внимание фильмам, которые получили государственную поддержку.
# Ответить на вопрос, насколько фильмы с государственной поддержкой интересны зрителю.
#
# Мы считали данные из двух файлов и объединили датафреймы по номеру прокатного удостоверения
#
# Увидели, что:
# - Есть пропуски
# - Есть дублирующиеся названия
# - Много категорийных столбцов с текстовым наполнением - это приводит к неявным дубликатам из-за лишних символов, неодинакового порядка перечислений и различных разделителей
#
# В первой части мы готовили данные для исследования, что сделали:
# 1. Проверили типы данных в датафрейме и преобразовали их там, где это необходимо:
# - `show_start_date` — дата премьеры фильма - преобразовали в `datetime`
# - `ratings` *—* рейтинг фильма на КиноПоиске - преобразовали в `float`. В рейтинге обнаружились значения с `%`. Мы проверили на Кинопоиске несколько фильмов - рейтинг ошибочен не только форматированием, но и значением.
#
# Категорийные столбцы оставили строковыми
#
# 2. В 11 столбцах были обнаружены пропуски. Мы обработали их и оставили пропуски в 3х:
# - `film_studio` - пропуски заполнили значением `unknown`
# - `production_country` - пропуски заполнили значением `Россия`
# - `director` - пропуски заполнили значением `unknown`
# - `producer` - пропуски заполнили значением `unknown`
# - `refundable_support` - пропуски заполнили `0`
# - `nonrefundable_support` - пропуски заполнили `0`
# - `budget` - поддержки не было, но заполнить `0` кажется неправильно, так как бюджет всё же не нулевой
# - `financing_source` - пропуски заполнили `none`
# - `ratings` - заполнить `0` кажется неправильно, так как рейтинг всё же не нулевой
# - `genres` - пропуски заполнили `unknown`
# - `box_office` - заполнить `0` кажется неправильно, так как рейтинг всё же не нулевой
# 3. Обработали дубликаты. В датафрейме много фильмов с одинаковыми данными, но разными прокатными удостоверениями. Также прокатные удостовериения, для которых была указана сумма в прокате `box_office` могли уже находиться в датафрейме под другими прокатными удостоверениями.
# 4. Общая проблема почти во всех категориальных столбцах:
# - перечисления нексольких объектов в разном порядке (порядок не изменяли, так как он может означать важность)
# - также встречаются разные способы разделения значений - через запятую или через `-` - исправили это на универсальные разделители
# 5. Столбец `budget` включал нулевые значения. Данные в этом столбце указаны только для тех фильмов, которые получили государственную поддержку. Значит, он не может быть меньше суммы поддержки. Приняли бюджет в этих строках равным сумме поддержки
# 6. Создали несколько новых столюцов для упрощения анализа
#
# #### Главные выводы.
# - Начиная с 2015 года бюджет фильмов с гос. поддержкой был в сумме 7 - 7.5 млрд. рублей. в 2019м году - рекордные 12.7 млрд. При этом в 2015, 2016 и 2019 годах эти бюджеты не окупились.
# - наиболее частые оценки для фильмов с господдержкой - 5.7 - 6.9 - это средний результат, зрители редко ставят им высокие оценки (максимум 8.5)
# - Фильмы, достигшие кассового успеха, соответственно и оценки имеют выше - чаще 6.4 - 7.6
# - Драма и комедия - наиболее часто пользуются гос. поддержкой, однако Комедия значительно чаще, чем драма имеет кассовый успех.
#
#
# #### Рекомендации.
# Есть рекомендации к данным:
# - использовать единый формат перечисления категорий и их разделители, главные значения категорий вывести в отдельные столбцы
# - если данные не известны, задавать для них какое-то значение, а не пропускать
